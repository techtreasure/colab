# %% [markdown]
# <a href="https://colab.research.google.com/github/techtreasure/colab/blob/master/Character_level_text_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction
#
# This is a simple text generation task using LSTM in Keras

# %% [markdown]
# ## Setup

# %%
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import random
import io

# %% [markdown]
# ## Data preperation

# %%
#Import the data file
path = keras.utils.get_file(
    "data.txt", origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt"
)

#Read the text file 
with io.open(path, encoding="utf-8") as f:
    text = f.read().lower()

#Eliminate new lines from the text
text = text.replace("\n", " ")
print("Corpus length:", len(text))

#Extract unique charactors 
chars = sorted(list(set(text)))
print("Total chars:", len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

#Extract fixed length semi-reducndent text sequences from the text file
#Each text sequece is in length of 40 charactors and striding with step 3
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i : i + maxlen]) # sequence with 40 chars
    next_chars.append(text[i + maxlen]) # next character for as the label
print("Number of sequences:", len(sentences))

#Reshape the data to feed in to LSTM model
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 2us/step
# Corpus length: 600893
# Total chars: 56
# Number of sequences: 200285

# %% [markdown]
# ## Build the model: a single LSTM layer

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(maxlen, len(chars))), #Visible layer
        layers.LSTM(128), #Hidden layer
        layers.Dense(len(chars), activation="softmax"),
    ]
)
optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss="categorical_crossentropy", optimizer=optimizer)

# %% [markdown]
# ## Train the model

# %%
epochs = 40 # can try higer values 
batch_size = 128

for epoch in range(epochs):
    model.fit(x, y, batch_size=batch_size, epochs=1)
    print()
    print("Epoch : %d" % epoch)

    
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated = ""
    #Extract a random sequence with 40 chars
    sentence = text[start_index : start_index + maxlen]
    print('Starting part of the sentence: "' + sentence + '"')

    for i in range(400): # predict 400 chars 
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.0
        preds = model.predict(x_pred, verbose=0)[0] 
        next_index = np.argmax(preds) # Select the higest probable char
        next_char = indices_char[next_index]

        #Append the predicted char and remove the first char of the sentece 
        #(to maintain the maxlength )
        sentence = sentence[1:] + next_char  
        generated += next_char

    print("Generated text sequence : ", generated)
    print()
# Out:
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.9148
#
# Epoch : 0
# Starting part of the sentence: "laced, and not yet a race, much less suc"
# Generated text sequence :  h a profound and soul themselves to the self--and and soul themselves to the self--and and soul themselves to the self--and and soul themselves to the self--and and soul themselves to the self--and and soul themselves to the self--and and soul themselves to the self--and and soul themselves to the self--and and soul themselves to the self--and and soul themselves to the self--and and soul themselv
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.5642
#
# Epoch : 1
# Starting part of the sentence: "ediocre everlasting,      sans genie et "
# Generated text sequence :  in the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the stand to the sta
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.4761
#
# Epoch : 2
# Starting part of the sentence: "not all gods hitherto been such sanctifi"
# Generated text sequence :  ed and sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sen
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.4325
#
# Epoch : 3
# Starting part of the sentence: "position would run: a thing[17] cannot a"
# Generated text sequence :  nd the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sen
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.4034
#
# Epoch : 4
# Starting part of the sentence: "torically, in the mysteries of demeter a"
# Generated text sequence :  nd soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the soul of the s
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.3821
#
# Epoch : 5
# Starting part of the sentence: "ion lies at the bottom of all this.   12"
# Generated text sequence :    =the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sen
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.3639
#
# Epoch : 6
# Starting part of the sentence: "gists, study the philosophy of the "rule"
# Generated text sequence :   of the substance of the substance of the substance of the substance of the substance of the substance of the substance of the substance of the substance of the substance of the substance of the substance of the substance of the substance of the substance of the substance of the substance of the substance of the substance of the substance of the substance of the substance of the substance of the s
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.3502
#
# Epoch : 7
# Starting part of the sentence: ".   119  =fate of christianity.=--christ"
# Generated text sequence :  ian constitutes of the same are the sense of the same are the sense of the same are the sense of the same are the sense of the same are the sense of the same are the sense of the same are the sense of the same are the sense of the same are the sense of the same are the sense of the same are the sense of the same are the sense of the same are the sense of the same are the sense of the same are the
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.3377
#
# Epoch : 8
# Starting part of the sentence: "hey have hitherto had something better t"
# Generated text sequence :  he sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense o
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.3289
#
# Epoch : 9
# Starting part of the sentence: "int, as the enigma of self-subjugation a"
# Generated text sequence :  nd state of the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the strange the
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.3194
#
# Epoch : 10
# Starting part of the sentence: "wards us has a free will in the matter a"
# Generated text sequence :  nd the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sen
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.3108
#
# Epoch : 11
# Starting part of the sentence: " if mankind had known from the beginning"
# Generated text sequence :   of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the se
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.3050
#
# Epoch : 12
# Starting part of the sentence: "therefore unjust. the vice of the judgme"
# Generated text sequence :  nt of the sensation of the sensation of the sensation of the sensation of the sensation of the sensation of the sensation of the sensation of the sensation of the sensation of the sensation of the sensation of the sensation of the sensation of the sensation of the sensation of the sensation of the sensation of the sensation of the sensation of the sensation of the sensation of the sensation of the
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2975
#
# Epoch : 13
# Starting part of the sentence: "ychological observation--is among the me"
# Generated text sequence :  n of the sentiment of the sentiment of the sentiment of the sentiment of the sentiment of the sentiment of the sentiment of the sentiment of the sentiment of the sentiment of the sentiment of the sentiment of the sentiment of the sentiment of the sentiment of the sentiment of the sentiment of the sentiment of the sentiment of the sentiment of the sentiment of the sentiment of the sentiment of the
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2902
#
# Epoch : 14
# Starting part of the sentence: ". it is a very varying thing and one clo"
# Generated text sequence :  sely and the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the strong the st
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.2850
#
# Epoch : 15
# Starting part of the sentence: "s with that commendation: in short, whet"
# Generated text sequence :  her the strange the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sen
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2806
#
# Epoch : 16
# Starting part of the sentence: "of the instinct which divines that truth"
# Generated text sequence :   in the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the strength, the
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2774
#
# Epoch : 17
# Starting part of the sentence: "im stronger, more evil, and more profoun"
# Generated text sequence :  d the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sens
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2713
#
# Epoch : 18
# Starting part of the sentence: "ke them furious, i shall take care not t"
# Generated text sequence :  he subjection of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the strength of
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2681
#
# Epoch : 19
# Starting part of the sentence: "attachments, to which sense and heart pr"
# Generated text sequence :  esent the superstination of the stronger the superstination of the stronger the superstination of the stronger the superstination of the stronger the superstination of the stronger the superstination of the stronger the superstination of the stronger the superstination of the stronger the superstination of the stronger the superstination of the stronger the superstination of the stronger the super
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2643
#
# Epoch : 20
# Starting part of the sentence: " gaze long into an abyss, the abyss will"
# Generated text sequence :   all the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the s
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.2599
#
# Epoch : 21
# Starting part of the sentence: "--for "woman".  87. fettered heart, free"
# Generated text sequence :  dom the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the se
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2569
#
# Epoch : 22
# Starting part of the sentence: "hich is wisdom in itself, inasmuch as al"
# Generated text sequence :  l the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sens
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2532
#
# Epoch : 23
# Starting part of the sentence: "y distinguished, but each with an attrib"
# Generated text sequence :  le to the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2495
#
# Epoch : 24
# Starting part of the sentence: "n is something that can be grown out of;"
# Generated text sequence :   and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and actions and
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2479
#
# Epoch : 25
# Starting part of the sentence: "mpersonal than when looked at in their s"
# Generated text sequence :  trict and conscience and all the strict of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the s
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.2449
#
# Epoch : 26
# Starting part of the sentence: "nst his will.=--in a certain movement th"
# Generated text sequence :  at the strength, and a strength, and the strength, and the strength, and the strength, and the strength, and the strength, and the strength, and the strength, and the strength, and the strength, and the strength, and the strength, and the strength, and the strength, and the strength, and the strength, and the strength, and the strength, and the strength, and the strength, and the strength, and the
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2411
#
# Epoch : 27
# Starting part of the sentence: "houghts, however, are the greatest event"
# Generated text sequence :  s and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an and an
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.2391
#
# Epoch : 28
# Starting part of the sentence: " along which they travel?   3  it may be"
# Generated text sequence :   a strong to the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the same as the
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.2360
#
# Epoch : 29
# Starting part of the sentence: "well as the native--this book has been r"
# Generated text sequence :  esults the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of the spirit of t
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2363
#
# Epoch : 30
# Starting part of the sentence: "n go so far, on this account, as to over"
# Generated text sequence :  cect of the senses of the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the strang the
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.2326
#
# Epoch : 31
# Starting part of the sentence: "nce so dreadful, questioning, and questi"
# Generated text sequence :  ons of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.2293
#
# Epoch : 32
# Starting part of the sentence: "hich is not intentional, and that all it"
# Generated text sequence :  s conditional the strength of the strange of the strange and an and decisive and an an action in the sense of the strange of the strange and an and decisive and an an action in the sense of the strange of the strange and an and decisive and an an action in the sense of the strange of the strange and an and decisive and an an action in the sense of the strange of the strange and an and decisive and
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.2272
#
# Epoch : 33
# Starting part of the sentence: " been gone through a hundred times: the "
# Generated text sequence :  stands the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the standard of the stand
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2264
#
# Epoch : 34
# Starting part of the sentence: "ost carefully avoid all hot-headed rival"
# Generated text sequence :  ity.   101  =the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.2242
#
# Epoch : 35
# Starting part of the sentence: " have considerable doubt as to whether w"
# Generated text sequence :  ith the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2215
#
# Epoch : 36
# Starting part of the sentence: "ence within them. but this is but a theo"
# Generated text sequence :  logical preservation of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the senses o
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2200
#
# Epoch : 37
# Starting part of the sentence: "st, acutest, and perhaps also filthiest "
# Generated text sequence :  and the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the se
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2187
#
# Epoch : 38
# Starting part of the sentence: "gest, the soul-atomism. let it be permit"
# Generated text sequence :  ted to the superiority of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2162
#
# Epoch : 39
# Starting part of the sentence: "urality always presupposes that _somethi"
# Generated text sequence :  ng the strang to the sense of the sense, and and the strang to the sense of the sense, and and the strang to the sense of the sense, and and the strang to the sense of the sense, and and the strang to the sense of the sense, and and the strang to the sense of the sense, and and the strang to the sense of the sense, and and the strang to the sense of the sense, and and the strang to the sense of th

# %% [markdown]
# #Helper function for Sampling

# %%
def sample(preds, temperature=1.0):
    EPSILON = 10e-16 # to avoid taking the log of zero
    preds = (np.asarray(preds) + EPSILON).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
epochs = 40
batch_size = 128

for epoch in range(epochs):
    model.fit(x, y, batch_size=batch_size, epochs=1)
    print()
    print("Epoch : %d" % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print("...Diversity:", diversity)

        generated = ""
        sentence = text[start_index : start_index + maxlen]
        print('Starting part of the sentence: "' + sentence + '"')

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.0
            preds = model.predict(x_pred, verbose=0)[0]

            # test for different diversities
            next_index = sample(preds, diversity) 
            next_char = indices_char[next_index]
            sentence = sentence[1:] + next_char
            generated += next_char

        print("Generated text sequence : ", generated)
        print()
# Out:
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2087
#
# Epoch : 0
# ...Diversity: 0.2
# Starting part of the sentence: " acquired, circumscribed needs, based up"
# Generated text sequence :  on the head, and in the soul in the standard of the soul of the sense, is a particing the sense of the sense of the sense of the soul of the same always as the world, as a probably, and all the conscious of the substation of the sense of the world, and when it is a principle of the standard of the sense of the sense of the sense of the soul of the strength of the conscious of the most deceive of t
#
# ...Diversity: 0.5
# Starting part of the sentence: " acquired, circumscribed needs, based up"
# Generated text sequence :  on the whole opposite of some consideration of the more possible and his world, the christianity the strong and discove as the fact that the place of the present subsusments, it is esgress simply in englious and wised, in the scientific sense--itself and different afficic of the conscious with a most addear in the possible the herdence of the most love the most deceive in the world of the stander
#
# ...Diversity: 1.0
# Starting part of the sentence: " acquired, circumscribed needs, based up"
# Generated text sequence :  on his analises, but the hundrerly the disponsibility of modern its knowledge of this jew, imported as possible in serious irrpullatable: this very wines any means, induce that beconsificanced, there is conduct of the libing.=--the standineciom, cilminable, theps in fact than toto faine to its learned have defepre areight to dress, a part of spirits; and fingtidious constinctive for itself; corrad
#
# ...Diversity: 1.2
# Starting part of the sentence: " acquired, circumscribed needs, based up"
# Generated text sequence :  on inti"urs, asward indeptath carable, sole seleined, very wile, in sabvprit virtue and interromic only then maut sedicially, nothing or, upon has it is tonesened of heartincuvs "theie, thereyould he sull: ving offarilly helponment: in everything bad" capt "two work apes--when the remorouping, a you est remutious sprink, or has neighar aspewlent, would have endureraned my, superiods--even the caus
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2068
#
# Epoch : 1
# ...Diversity: 0.2
# Starting part of the sentence: "ish a criminal and inflict pain upon him"
# Generated text sequence :  self and interpretation and the person of the protecting of the senseful of the protection of the protection of the spectarlery of the protest and conscience of the contrast in the senseful and strength of the grand of the great and process of the protecting of the former of the sense of the protection of the senses of the sense of the sense of the sense of the senseful and and the power of the pr
#
# ...Diversity: 0.5
# Starting part of the sentence: "ish a criminal and inflict pain upon him"
# Generated text sequence :   to be man therefore in all the conscience man of the more more possession where sometions, for the onk who is the freect he fain interest to a philosopher explination: a man here and beings a spectarly and action the word and person the free who only the spirit, and is the contrast and standard of the former interrorious strength, and and accepted, is the supereful or a part as is it seems to the
#
# ...Diversity: 1.0
# Starting part of the sentence: "ish a criminal and inflict pain upon him"
# Generated text sequence :  mation world, ignorant, the personal and they say who log everything itsily in a god, appearance. may fathersn; the age of genius you kill, egois-cospered and events man that a gace in freels of life, "order to feel it reduced whe exhaust individuation of a deals thereby generes, has been take upon belief these free with their one the dangerous penpo, as a apart," the privilegation mots which woul
#
# ...Diversity: 1.2
# Starting part of the sentence: "ish a criminal and inflict pain upon him"
# Generated text sequence :  , we fain of their injume finalny, whose,--that is--for!nitaket propery. it for least) and never the mast-brassing as its purily spirits.--seek. "when enor a mean any same, little, how has prouded tear of a questions must liken of whom a surxaminesss of decelfied, each root the kind ofiging at the reais of man anything tofoes: the woman has to greatly persond why perpetual god" in this us, while a
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2068
#
# Epoch : 2
# ...Diversity: 0.2
# Starting part of the sentence: "ng concerning morals might be conducted "
# Generated text sequence :  to the soul of the most desiration of the power, and who are all the sensations of the soul of the sensation of the soul of the sensation of the strength of the world of the problem of the subject of the sensation of the pain of conception of the desirable the sensation of the soul of the conscience of the sensation of the soul of the soul of the problem of the strength of the same as the heart of
#
# ...Diversity: 0.5
# Starting part of the sentence: "ng concerning morals might be conducted "
# Generated text sequence :  the work of the soul. in the secise the thinkers is in the experience of the problems of the most serve and an experience the new cried the probably been little the strength of the wrenches of the philosophers in the manifestation of the secret will and even in himself so fact that he will not be one of the secret be insist of the powerles in the subject of the most conscience of the possibes of t
#
# ...Diversity: 1.0
# Starting part of the sentence: "ng concerning morals might be conducted "
# Generated text sequence :  exaltegly that the possible day. not a kind when a man so of reyleded and most standardsmen and we knows manificiling, for they see ohing with friend how the regard of man to the notion of a head, and importance--inave most too commanding that hardeticaters the evil of a bo": why conferlitation of all part, and for effevoluth would choes the subpremial question, with lightness to like the portalou
#
# ...Diversity: 1.2
# Starting part of the sentence: "ng concerning morals might be conducted "
# Generated text sequence :  in "confecred as free would alreade pregres! this old proifshed this erroobomic polent, thas "degradehing who are hi?-neckmioned we , says principeled for some frenchful has fore-xus by  has, from his ear duties.nession, here ha-lilers, and frrentified, alreadynes, disrice.  sre! but or as it need according of  takes itself cannot lighted once as expentive it about keepinwow, and good where noble
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2043
#
# Epoch : 3
# ...Diversity: 0.2
# Starting part of the sentence: " a german is almost incapacitated for pr"
# Generated text sequence :  evaies and subtlest and something the self-deception of the contrary of the sense of the sense of the sense of the same as in the same as a present sense, which we are so that the soul and the spiritual and standard of the world of the species and most superst of the sense of the standard of the soul of the sense of the spiritual contrary in the soul the most more the spiritual contrary of the sou
#
# ...Diversity: 0.5
# Starting part of the sentence: " a german is almost incapacitated for pr"
# Generated text sequence :  obably the most has always be the most may say in so races and suppression of the soul and we standard of the value of the sense of the same respect of the significance of which the world in the first of the past of the religious and influence of the most paintered and the decising of the secret of a source of the most serve of the significance of the same retences and man of such with the and oth
#
# ...Diversity: 1.0
# Starting part of the sentence: " a german is almost incapacitated for pr"
# Generated text sequence :  oper with religious prefery, belief in others, would lave depley is in the tribful who believing are his creationan but instepness of aisepurant one ingot of onegmurs. in the misreal for. the word on ent no means now, always from recognize, shapres any conscience, "dismosed to delivet to dutt severity however, except among things--which coming soul from as insys, he deromphy hit former. the powers
#
# ...Diversity: 1.2
# Starting part of the sentence: " a german is almost incapacitated for pr"
# Generated text sequence :  assing and horshorks), and woman be out of others as so "kind his denitifation by esverning forls, sogness to arouse-more, does up appeared; in all lateo: willveal condupting assume our ideas. obsere" are probabilly? in educated the development of utter what "eramurs askitged go, sepeliwiyg! but or wele, do perionasion with his sehd of the eables for a thing so losig every burbter sought-curious d
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2041
#
# Epoch : 4
# ...Diversity: 0.2
# Starting part of the sentence: "r than actually built: this is owing to "
# Generated text sequence :  the strength of the master of the strength of a sense of the strength,ole c'ullably and actions. the sense of the probability of the consideration of the sublime of the strength, lat the strength of the sense of the strength of all the subject of the strength of the present and protest of the strength of the present of the strength of the strength of the strength of the philosophy and delicate of
#
# ...Diversity: 0.5
# Starting part of the sentence: "r than actually built: this is owing to "
# Generated text sequence :  the is the delicate of such a person is there is a philosophy is not everything which has been science must be punishments and discoverent physiologists and fact the experience the condition of the thought things--as the sense of the following for the great certain contemplation and strength,ole glows is not men both remote the experience the possess of the most distrustpulous sentiment of the lam
#
# ...Diversity: 1.0
# Starting part of the sentence: "r than actually built: this is owing to "
# Generated text sequence :  ridatud myself the evolute of some threater against of all try of arcession law;--so? is someone the difficult with their "admineally strively of tyrannly xuble such a really in the truth of a difference--this sense, more mart does what not tente wrong be ulterally, in the consideration of done, itself precisely in the must of politices its future.  ned have the si. the sound that it belongs times
#
# ...Diversity: 1.2
# Starting part of the sentence: "r than actually built: this is owing to "
# Generated text sequence :  some means of will-they werelt irimily of shmestally corrrour masterly requircing toalsrave no love, "which harder is affacticiance of meldonhed this truth is humble lived to epicurug did otnowed list gor this skeptical science prassed repeat, he denething the christianity lacking, with certain cifere. why is just from it developping. what, seept hence foll?--to up took. this ludumative, yle) real
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.2012
#
# Epoch : 5
# ...Diversity: 0.2
# Starting part of the sentence: "ruders, though they may dash and break t"
# Generated text sequence :  o the sense of the sense and problem of the same asses and his soul it is the superior of the problem of the superior of the senses of the superior of the same asses and have the spirit have been the strength of the senses of the senses of the soul of the sense of the spirit have the sense of the senses of the sense--that is the will to the sense of the soul it will be the senses of the such a sup
#
# ...Diversity: 0.5
# Starting part of the sentence: "ruders, though they may dash and break t"
# Generated text sequence :  o exting, and the world in the spirit of the sense--that is not themselves to the saint that the sensation of the future of individuals what one would not to the sensand and such a religious conscience which has a thing that his fall that is the process of the soul. what other and sensations of represental principal as the sensance that is the "nount and dependent of the senses of such a loftient
#
# ...Diversity: 1.0
# Starting part of the sentence: "ruders, though they may dash and break t"
# Generated text sequence :  hat i minders of human does finer itself is inspire their earching both predication that a goal in the sign of the whorverity of beadiaus of tly self action for "powerful, that we never purity--and a consequences of because of voluntaring, is not experion that seen to trilifeure, there is their generament, at present, the worst from faith not will be to maintainity what we seems to eternal, of an
#
# ...Diversity: 1.2
# Starting part of the sentence: "ruders, though they may dash and break t"
# Generated text sequence :  hics. nament, as so is kind of the supremahital sense a jesum prosists of time waridue ciection, life for their inmult belongs to kees generation of exists is how old mynecting" in roate ahound is designated peculates and as any erronplies--at one typit-ne-posic, creal purpas oricially--and ut and purplates name to be clearfulacter opinions: aken of human trained as , on the most rumcimints to for
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.1986
#
# Epoch : 6
# ...Diversity: 0.2
# Starting part of the sentence: "the generations which are contemporary w"
# Generated text sequence :  ith the soul-in the senses of the senses into the latter of the spirit of the senses of the will of the senses of the soul in the spirit of the profound of the soul a state of the senses of the soul of the senses of the state of the soul, and all the senses of the consciousness of the senses of the superior of the senses of the soul of the senses of the senses of the soul of the senses of the stat
#
# ...Diversity: 0.5
# Starting part of the sentence: "the generations which are contemporary w"
# Generated text sequence :  ith the general men, something and belong so discipreations and seen and the strangest and most extent the presenting of the scientificnce in the senseing that it is a soul is an absolutely and with the sense--what is the soul that seem to one feel the same althowed heart which we so suddeminy in order to one will only a comprehension of the other is regarded all the soul in the explanation of whi
#
# ...Diversity: 1.0
# Starting part of the sentence: "the generations which are contemporary w"
# Generated text sequence :  ith strange for novoled to difficive of a name of the scientificn of duties of world, resciselves thought a the univortaining to beings to a forthen; that "ratherly." the secrals, of bleed from that we indeniege toperate the existencine very conception of conception of the perrim is worthe. the fight, is been by who seeked a of the whole kinds of scarnity shapes itself trees the consise sense, in
#
# ...Diversity: 1.2
# Starting part of the sentence: "the generations which are contemporary w"
# Generated text sequence :  ith those in involved it more ane" presenvated for call should have been generative. that everything as the gods hall---ihermotion. confined too duliest after observatione is thrich has maf a nations of praves. much a judge in theirlies--others? and petcy pain, which. every judgment, the heart,--"they many, the explanation in the striving and exhause on the membimal intoligificting, a soul a metap
#
# 1565/1565 [==============================] - 7s 5ms/step - loss: 1.1971
#
# Epoch : 7
# ...Diversity: 0.2
# Starting part of the sentence: "the world has gradually become so wondro"
# Generated text sequence :  und in the streem of the streem of the sense, and is the subject of the senses of the most subject, and in the senses of the sense of the probably the streautify the sense, and is all the conscience of the most subject, and is the spiritual spirit who would be the long as the most condition of the condition of the senses of the subject of the streem of the act of the sense of the senses of the mos
#
# ...Diversity: 0.5
# Starting part of the sentence: "the world has gradually become so wondro"
# Generated text sequence :  wed to men of the protection of the contrast of success--it is not to the shame the world and interprete of a morality, in their simultable with it also and dread, and a deceptive humanity in the strempois it in an excessive outlovent of the sensial distress of the most subject, and in the fact that the unimable and history of the earth," who of the more instinct to the extent the things will the
#
# ...Diversity: 1.0
# Starting part of the sentence: "the world has gradually become so wondro"
# Generated text sequence :  und, how terfeming of the mainteration of famougats was not on the conditionating the applies, how to botherness, but in ourselves are give a right of everything progressbmuct--knows in order the mainlation of vallicishe, and the turn from the bruth with desire and whought ut that shallogitude of whomperoration, i pluel lime has all ormations, and at a denence, all good, who sfrom, from the made "
#
# ...Diversity: 1.2
# Starting part of the sentence: "the world has gradually become so wondro"
# Generated text sequence :  wn-ekes to exablly certain apprehensible sofhe, self-mulce, for meriteses; also man in that him, would there would be instincils; worth lopes agnious.  among divewnse if be cedues areable for tenscoronarist, for instance, who skeptic fof the rarence knowledge, but good watny long wither." whither-lifating, animals, threatenment at the light, as to wormnelis-day.   d      whilt ape's looks an haugh
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.1964
#
# Epoch : 8
# ...Diversity: 0.2
# Starting part of the sentence: " prevalence of an opposite belief. they "
# Generated text sequence :  are superiors and the spectace and the most and strength of its contrast, as the such a sure to the production of the spirit, and all the struggle of the spectace the spirit of the spectace the superiority of the process of the strength of an active and prospect and the world of the superior of the present of the conscience of the spirit, and the senses of the strength of all the struggle of the s
#
# ...Diversity: 0.5
# Starting part of the sentence: " prevalence of an opposite belief. they "
# Generated text sequence :  are as in the former and as in fact, and we such a passion of the protecting of his the proses, in the "stridic and with its influence, the other contrast in the strength of the christian of the conscious future of this will are civilizations. the fully for the play indeed it seems to him, to be nothing is superiors and who free thing of the races and from itself that it is possibly for this for w
#
# ...Diversity: 1.0
# Starting part of the sentence: " prevalence of an opposite belief. they "
# Generated text sequence :  which suffers the wors!" od himself alif fears!" in imakenikable ideas, dream-non--finally accumunt, good" and gafing couragots of love be experiencred in revenceive nature step is here vanity, indenderousness, with honour of one to punishorate of dictum word in the symentalness iy,wes racearn for the belief of an indegenth of vengence by that shart, as camlation but a pass--ared opinntoret--who e
#
# ...Diversity: 1.2
# Starting part of the sentence: " prevalence of an opposite belief. they "
# Generated text sequence :  have with mind af": he class, toat on man a thing"! ixaisity; followited to cavers, possible away applifey suds, we berouquls canald, they glantures, remained yet lakes but christianify, as to said wise for every wartt,      peocaue, itself are tracful's and hat so, so that i was neceptio men. for secrutistic indrediest make list to life as less, stranges! helquess gacese. this sage a mo values to
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.1954
#
# Epoch : 9
# ...Diversity: 0.2
# Starting part of the sentence: "owness and mystery, of the too-near, of "
# Generated text sequence :  the more and more the sense of the sense of all the sense of the sense of the sense of man selfind in the conscience of the senses of the scientific man of the world of the subject, and in the same all the sense of the fact that the soul of the profound of the senses of the soul of the sense of the morality of the conscience of the sense of the senses which may be sures of the sense of the sense o
#
# ...Diversity: 0.5
# Starting part of the sentence: "owness and mystery, of the too-near, of "
# Generated text sequence :  the highest processes and evil above all the world world read to community which may be long sould man who every action of its invection, and always to beside to the enduring of the constraint, and an allang and soul of all the man consideration of with the subject of reason, would be the most sudden of the will to such man in the termed power to ecount of believe that one may believe himself, man
#
# ...Diversity: 1.0
# Starting part of the sentence: "owness and mystery, of the too-near, of "
# Generated text sequence :  comminigation, under eremoring merely is suwerethring substance stap by the chrests of sacrifice" its linfer but to convertion be may regard to effoundent way in the world, an actual give the reperely ala--to he, cant is all stage--the firlem of value established, cultims any awame nations; in the races wrong that is the world in socious interprete fron i permanted powers and play has a right of d
#
# ...Diversity: 1.2
# Starting part of the sentence: "owness and mystery, of the too-near, of "
# Generated text sequence :  which mulies while became his criess of theur, but to you. franted with their kind of obviount south--ignoliats; art arecess spirituality, us distrament fasned ared ancealed himself and dain was yet how--over-futured ammsem--into in the reblandams; men wamiped, and guise cam noneithumeal, woman) kkens war jown originatly remain flown who bad, assurencess of man who schearion in humanines? it tell-
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.1925
#
# Epoch : 10
# ...Diversity: 0.2
# Starting part of the sentence: "part of conscious thinking must be count"
# Generated text sequence :  erad to the world of the senses of the strength of the strange of the sense of the sense of the subject. the truths as the world in the sense of the sense of the world of the truths and the free spirit and present and most subject.   122
#
# ...Diversity: 0.5
# Starting part of the sentence: "part of conscious thinking must be count"
# Generated text sequence :  erfar by the strange and acts of the conception, and the world, and also all the senses of the strict of all significance of the problemtoric of the welference of the will of the most subject. it is the works; and what in every great summ with sensations in the same religion are in the foreion of such a sort of the "wishes as everything who of the religion of the sense.  2edy--one must it is "not
#
# ...Diversity: 1.0
# Starting part of the sentence: "part of conscious thinking must be count"
# Generated text sequence :  ait, and side nature incapacisms. magnehse" had a ridal reservate the sugc. he has ideaphers to easy, inteltiness, interesten araud, the sacrific centurient discaply instrument of the end was for alone. they must lead, life, effect, the concegnifications of our possible. they invent, this weabiliation of this weaks and past, a maloony in the confess for wet the behalf the say of fictiesy, break me
#
# ...Diversity: 1.2
# Starting part of the sentence: "part of conscious thinking must be count"
# Generated text sequence :  s invention for the world wapse.  2aly preshedet. man" even its relect comings, could beding superstives them) must, , that goman had even wind? and fund, has "true to different taste, errot in the fore is vanitumves of the surpuces: depended into others; there is adamious ovglines greet bear? by ait in "what is saiptdatike and this. there coaration as a conrrepoined; all contoritera" unconcekingl
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.1928
#
# Epoch : 11
# ...Diversity: 0.2
# Starting part of the sentence: "ermined decision and answer to predeterm"
# Generated text sequence :   and the freedom in the standard of the sense of the morality of the probably the experience of the most probably the morality of the protection of the most subject, and the morality of the consideration of the probably the senses of the sense of the morality of the morality of the means of the senses of the sense of the state of the morality of the consideration of the probably the senses of the
#
# ...Diversity: 0.5
# Starting part of the sentence: "ermined decision and answer to predeterm"
# Generated text sequence :   there are the too indignism, in the motive of the world, as a respect of "the case the world have the state of the subject, and its artle as a new men is the fusubating, the pounted and indesgation of complipance in the fact that is the presence of the sentiment of its own accustoms and in the world of the general experience the religious origin of the made the exercise and itself which had in th
#
# ...Diversity: 1.0
# Starting part of the sentence: "ermined decision and answer to predeterm"
# Generated text sequence :  ant to an an one sear no, says towad. not strange--and the taste is catedied as all things even inthesoless, and as i miserlap is, a deception of confrientively this one awage-eke, who has all the typice can this from "greeking as a lofties of benord shatre, stander by the head. dividumever, through the being permitt with means and will and purs fund in ideatimists the love of this existence knowl
#
# ...Diversity: 1.2
# Starting part of the sentence: "ermined decision and answer to predeterm"
# Generated text sequence :   that express of shart, to greethy every ppges, respected by the knowledge day, as something sympathy with nature and lamuation, that a moral southern. the ideas of pyates three who wrettion, aim is an "virtues of thre; that all magted easier from prolacly christ my wand uneasorathed unishes.=--that will be -probyigize". dack; who unknow suff narrance.b--roumscowur therefuuectuals of trelumpt in h
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.1901
#
# Epoch : 12
# ...Diversity: 0.2
# Starting part of the sentence: " rightly conceived. thus, where there ex"
# Generated text sequence :  ists of the soul and a scientific standing of the superfinition of the senses of the conclusion of the streed to the soul and man who are not to the conclusion of the streakest and most and all the street of the conception of the morality of the strength of the protection of the scientific satisfiction of the same time of the same all themselves to the streed to the constant of the senses of the c
#
# ...Diversity: 0.5
# Starting part of the sentence: " rightly conceived. thus, where there ex"
# Generated text sequence :  ists of the same problem and in all that the protection of such a truths and friends and and sublimity and in the masculies of the soul now any one wished to themselves and distrust--and is perhaps a south and the maintence of the virtues of his standard and since all the present of prevers of thing that the masculess of freedom of such a superiority of give the individuals to say to a man strengt
#
# ...Diversity: 1.0
# Starting part of the sentence: " rightly conceived. thus, where there ex"
# Generated text sequence :  istic rhemous many additional serence and generally be repknerettly desirest and human to bernowisment, impperitus believe. a sobwlits at presuatening, alas they knowledge is not the recurquent mean species, gree feeling: "but even the belief in which they rempeding. that is at man, that between as so tences that, is or morality strives to prevers comes one must nevered ullring from our freedy and
#
# ...Diversity: 1.2
# Starting part of the sentence: " rightly conceived. thus, where there ex"
# Generated text sequence :  pected aught. from is beter man is not win-freedom-curribilies the courfknlepiness of principally thememous; how time thes icolinous each otua toody so--a dida intellect to luster of )vors. regardednessness:--for is equally distrustualse" wamily, with ambitually all low roldesiawly inud, his condition young tlay perfitite. with thinkings of courage omilifated upon what gion, on things extraordinar
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.1892
#
# Epoch : 13
# ...Diversity: 0.2
# Starting part of the sentence: "cardinal instinct of an organic being. a"
# Generated text sequence :   man and the strength of the sensation of the sensation of the sensation of the tragite in the sensation of the strength of the freedom and as a present of the strange that it is the probability of the sensation of the sensation of the sensation of the sensation of the strength of the sensation of the soul of the probability of the general or in the sensation of the first of the sensation of the s
#
# ...Diversity: 0.5
# Starting part of the sentence: "cardinal instinct of an organic being. a"
# Generated text sequence :  nd he was the interrogable and life. the state of soul of man and self-extended, the feeling or in the uttion of feeling and desire to slees, and and this time or when he such a the opposite of the sensance of his notions of the suncluse and is the distrust of the soul of the most proport of a structical instinct of their erron of flatter of the resultion of his self-existence of the most interpre
#
# ...Diversity: 1.0
# Starting part of the sentence: "cardinal instinct of an organic being. a"
# Generated text sequence :  ll thou "ward which is science on that has reeknys in order to be nowadays are bernweus senciement, and loved their probabilace, their kind he is for what, has been really womans and strength, at in freedom of all disciplinign itself against capultus as we did perhise and bestormy observat, stricted annihilus, and be aimful strong privilegedore. that he as well are theysiy, they executurifects bet
#
# ...Diversity: 1.2
# Starting part of the sentence: "cardinal instinct of an organic being. a"
# Generated text sequence :   partition saminalnit?", and with all say and intellect type he knowledge, their belong, were, and , out of comproseation and weurows. the reason that the exubhations too, and europe, guillic society? take ahroun bedied to false the coarserfing psychological mord more extent the whole ludaring "motives night, acceddence of understands, was colfvicus, when this in itse--they sunsomed that is true,
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.1870
#
# Epoch : 14
# ...Diversity: 0.2
# Starting part of the sentence: "ty in ancient greece called themselves. "
# Generated text sequence :  the profound of the sense, and interprete to the strange of the strange of the sense, and and possible and suffering to the strange of the sense of the most delight of the strange of the sense, that the strange of the profound that the contemporary of the profound that is not to the struggle of the sense, and consist of the strange of the sense, is to the strange of the sense, and which is an and
#
# ...Diversity: 0.5
# Starting part of the sentence: "ty in ancient greece called themselves. "
# Generated text sequence :  the women and sacrifice as the same special of the sense of the world of the consciously contempt for the struggle of the souls of the worthing of the end and sense, grant itself the stand of the sight of probably natures, and does we evil and individuals to our self-experience and experience--and often to a philosophy which feels to the ordeal of the preservation, and which has not all the domain
#
# ...Diversity: 1.0
# Starting part of the sentence: "ty in ancient greece called themselves. "
# Generated text sequence :  we are nce, which exists to us illwered of but to us-caste--i had looks desire but itself no deligedly, indeed." or, and conorfic contempt, for all contsseh of silent present, them the serious promises--may be -the once must for to practical motive may presentareness and pity from the possibility. in a victors must, how it depression of any refinement, art at thise intages which is conscience to k
#
# ...Diversity: 1.2
# Starting part of the sentence: "ty in ancient greece called themselves. "
# Generated text sequence :  thue. this is ought, or every sensa.old, dread" is emporsterably was reauticing, will-action and ridorest underston his motic deferses, who, where an one mores, is collection, what hours and event, to opon as an emball nature. we mead--pradf through had, circuvsed moral "sexes; the glance pabrial of disclovition to ride, moral, has nay, or vanicating.  nanhate" ok:   1ded about thought afnare of d
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.1856
#
# Epoch : 15
# ...Diversity: 0.2
# Starting part of the sentence: "e wished to do away altogether with the "
# Generated text sequence :  strength of the power of the proporiation of the extravagant of the senses of the subjectaring of the senses of the probably and interpretations of the spectarles of the extraordinaness of the senses of the world the sense of the strength of the senses of the senses of the spectarles of the soul of the senses of the world of the senses of the senses of the senses of the same truth of the senses of
#
# ...Diversity: 0.5
# Starting part of the sentence: "e wished to do away altogether with the "
# Generated text sequence :  self as a seems to the senses well conclused that there is not the senses and interpretations that to this for the soul, in the fact that is and rares and utility of the spectarles of the same as the signifienty--and in all the end to the light of the constant that it is not such discovering has always he wishes to the deep that the amminer of an among the last things that the and extentual person
#
# ...Diversity: 1.0
# Starting part of the sentence: "e wished to do away altogether with the "
# Generated text sequence :  period of long solitudes beyond with remardly and delifer in wholes or from power of deef the god are on the personal obyseso, we proson there the countein of this state, but on exubler to say, it make connightle, too poles, by the purpor itself: hon the truth; it is permancles in this delignouration of cut for the deep to these upon knild our land! and inasmuchua viif in my god a women the think"
#
# ...Diversity: 1.2
# Starting part of the sentence: "e wished to do away altogether with the "
# Generated text sequence :  primitify immoral unbraint? to round would rahes in personable bottemning, comfours--to the personing, to sufficienty has among a coscred is not be valey upon appeaclerigm, for it and philojent insisted faporneats-equally in everything insistidalion, is not says, finstle noivok, it is unforce_ fllsecturs as importually, that has itself, was a yewlerness also a medity--tkn later.=--the freedom hand
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.1864
#
# Epoch : 16
# ...Diversity: 0.2
# Starting part of the sentence: "thing that elevates the individual above"
# Generated text sequence :   that is the former the strange and considers and an action of the strange that the man and all the spirit of the man and a problem of the spirit of the sense, in the case of the probably and the fact that is a present and more and evident of the masterlands" of the case of the spirit and an experience the strange of the strange that the power, and the subject, and a strange that the contrary of t
#
# ...Diversity: 0.5
# Starting part of the sentence: "thing that elevates the individual above"
# Generated text sequence :   that the taste of the masters of the soul no longer a desire is the case and as the contrary, to the higher for the sense of a thing is not regarded as a man strong the manner--and when the reason of all la distrust of the sense of another individual that has been or a great super-aniuvssion and more possibility of the great deviming the last free thing is the case the wand of the strength of the
#
# ...Diversity: 1.0
# Starting part of the sentence: "thing that elevates the individual above"
# Generated text sequence :   thre" and su. somselure--or withfodsian, the basis of which mediocre in the sempul the duties here untithe barly:--he suited. it). in anarper cheamd leadet of recognized that other responsibility, whereas they are not refres; the higher without it find tknound worthficnes once merely abeve alpery distinction-e"fply portenianful of these one are beed therebed, as the sense of fact, as to poist the
#
# ...Diversity: 1.2
# Starting part of the sentence: "thing that elevates the individual above"
# Generated text sequence :   all a tranited of wishet the even thems would sensation of victory. agkegrus "power; it even these know through it acts to one axed is more feel, cocration--thus he us"--christianus aressure to badne-muck liberty, shall towardle ever need distinction, perhaps an allities which, and her jurger think and world at the danger of unimauence now have not its dergions, and lightr the depth of nature of
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.1829
#
# Epoch : 17
# ...Diversity: 0.2
# Starting part of the sentence: "ss of his situation had to be increased "
# Generated text sequence :  and source the subject, and also the senses of the strange that it is a subject of an and principle and possibility of the senses of the senses of the subject, and the problem of the senses of the senses of the senses of the senses of the senses of the senses of the senses of the spirit of the senses of the senses of the problem of the senses of the strange the subject of the problem of the proble
#
# ...Diversity: 0.5
# Starting part of the sentence: "ss of his situation had to be increased "
# Generated text sequence :  to see ourselves and relations as the instinct of a common such a things and more developed that which is not the more an an an instinct of the subjection of the scorn on the most distinction to the art of your slee-the state of a real the spirit which have been before the soul of the man of the soul in the belief in the probability of every means of the end as in the senses which he has personali
#
# ...Diversity: 1.0
# Starting part of the sentence: "ss of his situation had to be increased "
# Generated text sequence :  to them, as a simplician intold own altility of such , almost be, domaid spirits the conscious of the world final patnomion of ao trus."                                                                                                                    god it fores, or the secrecy intruse and society in wholed the regard in brand his sapperal pessimismable a things my longings and qualist which is
#
# ...Diversity: 1.2
# Starting part of the sentence: "ss of his situation had to be increased "
# Generated text sequence :  south, there is a priincures itself socally a, all the mutuman expedinged, in the worlest let who coming toque.bph," pripated is a madesly of grante, for pained truthman, orivous beings this solitariblents. on the neignd which ready unslem.  1is ite takes free time--oh, !  valsies social spiritude, which, been muss sicktupar of old going this caxes, asso life may be every pearatafful forms  "do th
#
# 1565/1565 [==============================] - 8s 5ms/step - loss: 1.1844
#
# Epoch : 18
# ...Diversity: 0.2
# Starting part of the sentence: "usseau, when it danced round the tree of"
# Generated text sequence :   the sense--who has a self and process of the same sure of the proper motive of the sense, in the most process of the sense, which is the sense, which has a present, and accompherow what is not the sense--who is a principle the same standard of the sense--who has all the sense of the sense, and is a present the proporiation of the sense--while to the process of the sense, is the standards of the s
#
# ...Diversity: 0.5
# Starting part of the sentence: "usseau, when it danced round the tree of"

# %% [markdown]
# <a href="https://colab.research.google.com/github/techtreasure/colab/blob/master/RNN_music_genre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import os
import math
import librosa
import numpy as np
import librosa, librosa.display
from IPython.display import Audio
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
import tensorflow.keras as keras

# %%
#Dataset download to Google colab
# !rm -rf ./*
# !wget -O speech_commands_v0.01.tar.gz http://opihi.cs.uvic.ca/sound/genres.tar.gz
# !tar xzf speech_commands_v0.01.tar.gz 
# !ls
# Out:
# --2020-07-22 00:56:46--  http://opihi.cs.uvic.ca/sound/genres.tar.gz
# Resolving opihi.cs.uvic.ca (opihi.cs.uvic.ca)... 142.104.68.135
# Connecting to opihi.cs.uvic.ca (opihi.cs.uvic.ca)|142.104.68.135|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1225571541 (1.1G) [application/x-gzip]
# Saving to: ‘speech_commands_v0.01.tar.gz’
#
# speech_commands_v0. 100%[===================>]   1.14G   903KB/s    in 22m 27s
#
# 2020-07-22 01:19:14 (888 KB/s) - ‘speech_commands_v0.01.tar.gz’ saved [1225571541/1225571541]
#
# genres	speech_commands_v0.01.tar.gz

# %%
FIG_SIZE = (15,10)

file = 'genres/blues/blues.00000.wav'

# load audio file with Librosa
signal, sample_rate = librosa.load(file, sr=22050)

Audio(file)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# WAVEFORM
# display waveform
plt.figure(figsize=FIG_SIZE)
librosa.display.waveplot(signal, sample_rate, alpha=0.4)

plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Waveform")
# Out:
# Text(0.5, 1.0, 'Waveform')

# %%
# FFT -> power spectrum
# perform Fourier transform
fft = np.fft.fft(signal)

# calculate abs values on complex numbers to get magnitude
spectrum = np.abs(fft)

# create frequency variable
f = np.linspace(0, sample_rate, len(spectrum))

# take half of the spectrum and frequency
left_spectrum = spectrum[:int(len(spectrum)/2)]
left_f = f[:int(len(spectrum)/2)]

# plot spectrum
plt.figure(figsize=FIG_SIZE)
plt.plot(left_f, left_spectrum, alpha=0.4)
plt.xlabel("Frequency")
plt.ylabel("Magnitude")
plt.title("Power spectrum")
# Out:
# Text(0.5, 1.0, 'Power spectrum')

# %%
# (Short Term Fourier Transformation) STFT -> spectrogram

hop_length = 512 # in num. of samples
n_fft = 2048 # window in num. of samples

# calculate duration hop length and window in seconds
hop_length_duration = float(hop_length)/sample_rate
n_fft_duration = float(n_fft)/sample_rate

print("STFT hop length duration is: {}s".format(hop_length_duration))
print("STFT window duration is: {}s".format(n_fft_duration))

# perform stft
stft = librosa.stft(signal, n_fft=n_fft, hop_length=hop_length)

# calculate abs values on complex numbers to get magnitude
spectrogram = np.abs(stft)

# apply logarithm to cast amplitude to Decibels
log_spectrogram = librosa.amplitude_to_db(spectrogram)

plt.figure(figsize=FIG_SIZE)
librosa.display.specshow(log_spectrogram, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format="%+2.0f dB")
plt.title("Spectrogram (dB)")
# Out:
# STFT hop length duration is: 0.023219954648526078s
# STFT window duration is: 0.09287981859410431s
# Text(0.5, 1.0, 'Spectrogram (dB)')

# %%
# MFCCs
# The mel frequency cepstral coefficients (MFCCs) of a signal are a small set of features (usually about 10-20) 
# which concisely describe the overall shape of a spectral envelope. In MIR, it is often used to describe timbre.

# extract 13 MFCCs


MFCCs = librosa.feature.mfcc(signal, sample_rate, n_fft=n_fft, hop_length=hop_length, n_mfcc=13)

# display MFCCs
plt.figure(figsize=FIG_SIZE)
librosa.display.specshow(MFCCs, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("MFCC coefficients")
plt.colorbar()
plt.title("MFCCs")

# show plots
plt.show()

# %%
DATASET_PATH = "genres"
JSON_PATH = "data_10.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 30 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION

# %%
def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    """Extracts MFCCs from music dataset and saves them into a json file along witgh genre labels.

        :param dataset_path (str): Path to dataset
        :param json_path (str): Path to json file used to save MFCCs
        :param num_mfcc (int): Number of coefficients to extract
        :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        :param hop_length (int): Sliding window for FFT. Measured in # of samples
        :param: num_segments (int): Number of segments we want to divide sample tracks into
        :return:
        """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:

		            # load audio file
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                # process all segments of audio file
                for d in range(num_segments):

                    # calculate start and finish sample for current segment
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # extract mfcc
                    mfcc = librosa.feature.mfcc(signal[start:finish], sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                    mfcc = mfcc.T

                    # store only mfcc feature with expected number of vectors
                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)
                        print("{}, segment:{}".format(file_path, d+1))

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
save_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)
# Out:
# Streaming output truncated to the last 5000 lines.
# genres/jazz/jazz.00037.wav, segment:8
# genres/jazz/jazz.00037.wav, segment:9
# genres/jazz/jazz.00037.wav, segment:10
# genres/jazz/jazz.00074.wav, segment:1
# genres/jazz/jazz.00074.wav, segment:2
# genres/jazz/jazz.00074.wav, segment:3
# genres/jazz/jazz.00074.wav, segment:4
# genres/jazz/jazz.00074.wav, segment:5
# genres/jazz/jazz.00074.wav, segment:6
# genres/jazz/jazz.00074.wav, segment:7
# genres/jazz/jazz.00074.wav, segment:8
# genres/jazz/jazz.00074.wav, segment:9
# genres/jazz/jazz.00074.wav, segment:10
# genres/jazz/jazz.00039.wav, segment:1
# genres/jazz/jazz.00039.wav, segment:2
# genres/jazz/jazz.00039.wav, segment:3
# genres/jazz/jazz.00039.wav, segment:4
# genres/jazz/jazz.00039.wav, segment:5
# genres/jazz/jazz.00039.wav, segment:6
# genres/jazz/jazz.00039.wav, segment:7
# genres/jazz/jazz.00039.wav, segment:8
# genres/jazz/jazz.00039.wav, segment:9
# genres/jazz/jazz.00039.wav, segment:10
# genres/jazz/jazz.00017.wav, segment:1
# genres/jazz/jazz.00017.wav, segment:2
# genres/jazz/jazz.00017.wav, segment:3
# genres/jazz/jazz.00017.wav, segment:4
# genres/jazz/jazz.00017.wav, segment:5
# genres/jazz/jazz.00017.wav, segment:6
# genres/jazz/jazz.00017.wav, segment:7
# genres/jazz/jazz.00017.wav, segment:8
# genres/jazz/jazz.00017.wav, segment:9
# genres/jazz/jazz.00017.wav, segment:10
# genres/jazz/jazz.00093.wav, segment:1
# genres/jazz/jazz.00093.wav, segment:2
# genres/jazz/jazz.00093.wav, segment:3
# genres/jazz/jazz.00093.wav, segment:4
# genres/jazz/jazz.00093.wav, segment:5
# genres/jazz/jazz.00093.wav, segment:6
# genres/jazz/jazz.00093.wav, segment:7
# genres/jazz/jazz.00093.wav, segment:8
# genres/jazz/jazz.00093.wav, segment:9
# genres/jazz/jazz.00093.wav, segment:10
# genres/jazz/jazz.00015.wav, segment:1
# genres/jazz/jazz.00015.wav, segment:2
# genres/jazz/jazz.00015.wav, segment:3
# genres/jazz/jazz.00015.wav, segment:4
# genres/jazz/jazz.00015.wav, segment:5
# genres/jazz/jazz.00015.wav, segment:6
# genres/jazz/jazz.00015.wav, segment:7
# genres/jazz/jazz.00015.wav, segment:8
# genres/jazz/jazz.00015.wav, segment:9
# genres/jazz/jazz.00015.wav, segment:10
# genres/jazz/jazz.00024.wav, segment:1
# genres/jazz/jazz.00024.wav, segment:2
# genres/jazz/jazz.00024.wav, segment:3
# genres/jazz/jazz.00024.wav, segment:4
# genres/jazz/jazz.00024.wav, segment:5
# genres/jazz/jazz.00024.wav, segment:6
# genres/jazz/jazz.00024.wav, segment:7
# genres/jazz/jazz.00024.wav, segment:8
# genres/jazz/jazz.00024.wav, segment:9
# genres/jazz/jazz.00024.wav, segment:10
# genres/jazz/jazz.00056.wav, segment:1
# genres/jazz/jazz.00056.wav, segment:2
# genres/jazz/jazz.00056.wav, segment:3
# genres/jazz/jazz.00056.wav, segment:4
# genres/jazz/jazz.00056.wav, segment:5
# genres/jazz/jazz.00056.wav, segment:6
# genres/jazz/jazz.00056.wav, segment:7
# genres/jazz/jazz.00056.wav, segment:8
# genres/jazz/jazz.00056.wav, segment:9
# genres/jazz/jazz.00056.wav, segment:10
# genres/jazz/jazz.00077.wav, segment:1
# genres/jazz/jazz.00077.wav, segment:2
# genres/jazz/jazz.00077.wav, segment:3
# genres/jazz/jazz.00077.wav, segment:4
# genres/jazz/jazz.00077.wav, segment:5
# genres/jazz/jazz.00077.wav, segment:6
# genres/jazz/jazz.00077.wav, segment:7
# genres/jazz/jazz.00077.wav, segment:8
# genres/jazz/jazz.00077.wav, segment:9
# genres/jazz/jazz.00077.wav, segment:10
# genres/jazz/jazz.00060.wav, segment:1
# genres/jazz/jazz.00060.wav, segment:2
# genres/jazz/jazz.00060.wav, segment:3
# genres/jazz/jazz.00060.wav, segment:4
# genres/jazz/jazz.00060.wav, segment:5
# genres/jazz/jazz.00060.wav, segment:6
# genres/jazz/jazz.00060.wav, segment:7
# genres/jazz/jazz.00060.wav, segment:8
# genres/jazz/jazz.00060.wav, segment:9
# genres/jazz/jazz.00060.wav, segment:10
# genres/jazz/jazz.00020.wav, segment:1
# genres/jazz/jazz.00020.wav, segment:2
# genres/jazz/jazz.00020.wav, segment:3
# genres/jazz/jazz.00020.wav, segment:4
# genres/jazz/jazz.00020.wav, segment:5
# genres/jazz/jazz.00020.wav, segment:6
# genres/jazz/jazz.00020.wav, segment:7
# genres/jazz/jazz.00020.wav, segment:8
# genres/jazz/jazz.00020.wav, segment:9
# genres/jazz/jazz.00020.wav, segment:10
# genres/jazz/jazz.00092.wav, segment:1
# genres/jazz/jazz.00092.wav, segment:2
# genres/jazz/jazz.00092.wav, segment:3
# genres/jazz/jazz.00092.wav, segment:4
# genres/jazz/jazz.00092.wav, segment:5
# genres/jazz/jazz.00092.wav, segment:6
# genres/jazz/jazz.00092.wav, segment:7
# genres/jazz/jazz.00092.wav, segment:8
# genres/jazz/jazz.00092.wav, segment:9
# genres/jazz/jazz.00092.wav, segment:10
# genres/jazz/jazz.00083.wav, segment:1
# genres/jazz/jazz.00083.wav, segment:2
# genres/jazz/jazz.00083.wav, segment:3
# genres/jazz/jazz.00083.wav, segment:4
# genres/jazz/jazz.00083.wav, segment:5
# genres/jazz/jazz.00083.wav, segment:6
# genres/jazz/jazz.00083.wav, segment:7
# genres/jazz/jazz.00083.wav, segment:8
# genres/jazz/jazz.00083.wav, segment:9
# genres/jazz/jazz.00083.wav, segment:10
# genres/jazz/jazz.00001.wav, segment:1
# genres/jazz/jazz.00001.wav, segment:2
# genres/jazz/jazz.00001.wav, segment:3
# genres/jazz/jazz.00001.wav, segment:4
# genres/jazz/jazz.00001.wav, segment:5
# genres/jazz/jazz.00001.wav, segment:6
# genres/jazz/jazz.00001.wav, segment:7
# genres/jazz/jazz.00001.wav, segment:8
# genres/jazz/jazz.00001.wav, segment:9
# genres/jazz/jazz.00001.wav, segment:10
# genres/jazz/jazz.00022.wav, segment:1
# genres/jazz/jazz.00022.wav, segment:2
# genres/jazz/jazz.00022.wav, segment:3
# genres/jazz/jazz.00022.wav, segment:4
# genres/jazz/jazz.00022.wav, segment:5
# genres/jazz/jazz.00022.wav, segment:6
# genres/jazz/jazz.00022.wav, segment:7
# genres/jazz/jazz.00022.wav, segment:8
# genres/jazz/jazz.00022.wav, segment:9
# genres/jazz/jazz.00022.wav, segment:10
# genres/jazz/jazz.00059.wav, segment:1
# genres/jazz/jazz.00059.wav, segment:2
# genres/jazz/jazz.00059.wav, segment:3
# genres/jazz/jazz.00059.wav, segment:4
# genres/jazz/jazz.00059.wav, segment:5
# genres/jazz/jazz.00059.wav, segment:6
# genres/jazz/jazz.00059.wav, segment:7
# genres/jazz/jazz.00059.wav, segment:8
# genres/jazz/jazz.00059.wav, segment:9
# genres/jazz/jazz.00059.wav, segment:10
# genres/jazz/jazz.00043.wav, segment:1
# genres/jazz/jazz.00043.wav, segment:2
# genres/jazz/jazz.00043.wav, segment:3
# genres/jazz/jazz.00043.wav, segment:4
# genres/jazz/jazz.00043.wav, segment:5
# genres/jazz/jazz.00043.wav, segment:6
# genres/jazz/jazz.00043.wav, segment:7
# genres/jazz/jazz.00043.wav, segment:8
# genres/jazz/jazz.00043.wav, segment:9
# genres/jazz/jazz.00043.wav, segment:10
# genres/jazz/jazz.00045.wav, segment:1
# genres/jazz/jazz.00045.wav, segment:2
# genres/jazz/jazz.00045.wav, segment:3
# genres/jazz/jazz.00045.wav, segment:4
# genres/jazz/jazz.00045.wav, segment:5
# genres/jazz/jazz.00045.wav, segment:6
# genres/jazz/jazz.00045.wav, segment:7
# genres/jazz/jazz.00045.wav, segment:8
# genres/jazz/jazz.00045.wav, segment:9
# genres/jazz/jazz.00045.wav, segment:10
# genres/jazz/jazz.00002.wav, segment:1
# genres/jazz/jazz.00002.wav, segment:2
# genres/jazz/jazz.00002.wav, segment:3
# genres/jazz/jazz.00002.wav, segment:4
# genres/jazz/jazz.00002.wav, segment:5
# genres/jazz/jazz.00002.wav, segment:6
# genres/jazz/jazz.00002.wav, segment:7
# genres/jazz/jazz.00002.wav, segment:8
# genres/jazz/jazz.00002.wav, segment:9
# genres/jazz/jazz.00002.wav, segment:10
# genres/jazz/jazz.00084.wav, segment:1
# genres/jazz/jazz.00084.wav, segment:2
# genres/jazz/jazz.00084.wav, segment:3
# genres/jazz/jazz.00084.wav, segment:4
# genres/jazz/jazz.00084.wav, segment:5
# genres/jazz/jazz.00084.wav, segment:6
# genres/jazz/jazz.00084.wav, segment:7
# genres/jazz/jazz.00084.wav, segment:8
# genres/jazz/jazz.00084.wav, segment:9
# genres/jazz/jazz.00084.wav, segment:10
# genres/jazz/jazz.00041.wav, segment:1
# genres/jazz/jazz.00041.wav, segment:2
# genres/jazz/jazz.00041.wav, segment:3
# genres/jazz/jazz.00041.wav, segment:4
# genres/jazz/jazz.00041.wav, segment:5
# genres/jazz/jazz.00041.wav, segment:6
# genres/jazz/jazz.00041.wav, segment:7
# genres/jazz/jazz.00041.wav, segment:8
# genres/jazz/jazz.00041.wav, segment:9
# genres/jazz/jazz.00041.wav, segment:10
# genres/jazz/jazz.00091.wav, segment:1
# genres/jazz/jazz.00091.wav, segment:2
# genres/jazz/jazz.00091.wav, segment:3
# genres/jazz/jazz.00091.wav, segment:4
# genres/jazz/jazz.00091.wav, segment:5
# genres/jazz/jazz.00091.wav, segment:6
# genres/jazz/jazz.00091.wav, segment:7
# genres/jazz/jazz.00091.wav, segment:8
# genres/jazz/jazz.00091.wav, segment:9
# genres/jazz/jazz.00091.wav, segment:10
# genres/jazz/jazz.00066.wav, segment:1
# genres/jazz/jazz.00066.wav, segment:2
# genres/jazz/jazz.00066.wav, segment:3
# genres/jazz/jazz.00066.wav, segment:4
# genres/jazz/jazz.00066.wav, segment:5
# genres/jazz/jazz.00066.wav, segment:6
# genres/jazz/jazz.00066.wav, segment:7
# genres/jazz/jazz.00066.wav, segment:8
# genres/jazz/jazz.00066.wav, segment:9
# genres/jazz/jazz.00066.wav, segment:10
# genres/jazz/jazz.00064.wav, segment:1
# genres/jazz/jazz.00064.wav, segment:2
# genres/jazz/jazz.00064.wav, segment:3
# genres/jazz/jazz.00064.wav, segment:4
# genres/jazz/jazz.00064.wav, segment:5
# genres/jazz/jazz.00064.wav, segment:6
# genres/jazz/jazz.00064.wav, segment:7
# genres/jazz/jazz.00064.wav, segment:8
# genres/jazz/jazz.00064.wav, segment:9
# genres/jazz/jazz.00064.wav, segment:10
# genres/jazz/jazz.00040.wav, segment:1
# genres/jazz/jazz.00040.wav, segment:2
# genres/jazz/jazz.00040.wav, segment:3
# genres/jazz/jazz.00040.wav, segment:4
# genres/jazz/jazz.00040.wav, segment:5
# genres/jazz/jazz.00040.wav, segment:6
# genres/jazz/jazz.00040.wav, segment:7
# genres/jazz/jazz.00040.wav, segment:8
# genres/jazz/jazz.00040.wav, segment:9
# genres/jazz/jazz.00040.wav, segment:10
# genres/jazz/jazz.00009.wav, segment:1
# genres/jazz/jazz.00009.wav, segment:2
# genres/jazz/jazz.00009.wav, segment:3
# genres/jazz/jazz.00009.wav, segment:4
# genres/jazz/jazz.00009.wav, segment:5
# genres/jazz/jazz.00009.wav, segment:6
# genres/jazz/jazz.00009.wav, segment:7
# genres/jazz/jazz.00009.wav, segment:8
# genres/jazz/jazz.00009.wav, segment:9
# genres/jazz/jazz.00009.wav, segment:10
# genres/jazz/jazz.00053.wav, segment:1
# genres/jazz/jazz.00053.wav, segment:2
# genres/jazz/jazz.00053.wav, segment:3
# genres/jazz/jazz.00053.wav, segment:4
# genres/jazz/jazz.00053.wav, segment:5
# genres/jazz/jazz.00053.wav, segment:6
# genres/jazz/jazz.00053.wav, segment:7
# genres/jazz/jazz.00053.wav, segment:8
# genres/jazz/jazz.00053.wav, segment:9
# genres/jazz/jazz.00053.wav, segment:10
# genres/jazz/jazz.00098.wav, segment:1
# genres/jazz/jazz.00098.wav, segment:2
# genres/jazz/jazz.00098.wav, segment:3
# genres/jazz/jazz.00098.wav, segment:4
# genres/jazz/jazz.00098.wav, segment:5
# genres/jazz/jazz.00098.wav, segment:6
# genres/jazz/jazz.00098.wav, segment:7
# genres/jazz/jazz.00098.wav, segment:8
# genres/jazz/jazz.00098.wav, segment:9
# genres/jazz/jazz.00098.wav, segment:10
# genres/jazz/jazz.00011.wav, segment:1
# genres/jazz/jazz.00011.wav, segment:2
# genres/jazz/jazz.00011.wav, segment:3
# genres/jazz/jazz.00011.wav, segment:4
# genres/jazz/jazz.00011.wav, segment:5
# genres/jazz/jazz.00011.wav, segment:6
# genres/jazz/jazz.00011.wav, segment:7
# genres/jazz/jazz.00011.wav, segment:8
# genres/jazz/jazz.00011.wav, segment:9
# genres/jazz/jazz.00011.wav, segment:10
# genres/jazz/jazz.00058.wav, segment:1
# genres/jazz/jazz.00058.wav, segment:2
# genres/jazz/jazz.00058.wav, segment:3
# genres/jazz/jazz.00058.wav, segment:4
# genres/jazz/jazz.00058.wav, segment:5
# genres/jazz/jazz.00058.wav, segment:6
# genres/jazz/jazz.00058.wav, segment:7
# genres/jazz/jazz.00058.wav, segment:8
# genres/jazz/jazz.00058.wav, segment:9
# genres/jazz/jazz.00058.wav, segment:10
# genres/jazz/jazz.00027.wav, segment:1
# genres/jazz/jazz.00027.wav, segment:2
# genres/jazz/jazz.00027.wav, segment:3
# genres/jazz/jazz.00027.wav, segment:4
# genres/jazz/jazz.00027.wav, segment:5
# genres/jazz/jazz.00027.wav, segment:6
# genres/jazz/jazz.00027.wav, segment:7
# genres/jazz/jazz.00027.wav, segment:8
# genres/jazz/jazz.00027.wav, segment:9
# genres/jazz/jazz.00027.wav, segment:10
# genres/jazz/jazz.00012.wav, segment:1
# genres/jazz/jazz.00012.wav, segment:2
# genres/jazz/jazz.00012.wav, segment:3
# genres/jazz/jazz.00012.wav, segment:4
# genres/jazz/jazz.00012.wav, segment:5
# genres/jazz/jazz.00012.wav, segment:6
# genres/jazz/jazz.00012.wav, segment:7
# genres/jazz/jazz.00012.wav, segment:8
# genres/jazz/jazz.00012.wav, segment:9
# genres/jazz/jazz.00012.wav, segment:10
# genres/jazz/jazz.00068.wav, segment:1
# genres/jazz/jazz.00068.wav, segment:2
# genres/jazz/jazz.00068.wav, segment:3
# genres/jazz/jazz.00068.wav, segment:4
# genres/jazz/jazz.00068.wav, segment:5
# genres/jazz/jazz.00068.wav, segment:6
# genres/jazz/jazz.00068.wav, segment:7
# genres/jazz/jazz.00068.wav, segment:8
# genres/jazz/jazz.00068.wav, segment:9
# genres/jazz/jazz.00068.wav, segment:10
# genres/jazz/jazz.00065.wav, segment:1
# genres/jazz/jazz.00065.wav, segment:2
# genres/jazz/jazz.00065.wav, segment:3
# genres/jazz/jazz.00065.wav, segment:4
# genres/jazz/jazz.00065.wav, segment:5
# genres/jazz/jazz.00065.wav, segment:6
# genres/jazz/jazz.00065.wav, segment:7
# genres/jazz/jazz.00065.wav, segment:8
# genres/jazz/jazz.00065.wav, segment:9
# genres/jazz/jazz.00065.wav, segment:10
# genres/jazz/jazz.00047.wav, segment:1
# genres/jazz/jazz.00047.wav, segment:2
# genres/jazz/jazz.00047.wav, segment:3
# genres/jazz/jazz.00047.wav, segment:4
# genres/jazz/jazz.00047.wav, segment:5
# genres/jazz/jazz.00047.wav, segment:6
# genres/jazz/jazz.00047.wav, segment:7
# genres/jazz/jazz.00047.wav, segment:8
# genres/jazz/jazz.00047.wav, segment:9
# genres/jazz/jazz.00047.wav, segment:10
# genres/jazz/jazz.00087.wav, segment:1
# genres/jazz/jazz.00087.wav, segment:2
# genres/jazz/jazz.00087.wav, segment:3
# genres/jazz/jazz.00087.wav, segment:4
# genres/jazz/jazz.00087.wav, segment:5
# genres/jazz/jazz.00087.wav, segment:6
# genres/jazz/jazz.00087.wav, segment:7
# genres/jazz/jazz.00087.wav, segment:8
# genres/jazz/jazz.00087.wav, segment:9
# genres/jazz/jazz.00087.wav, segment:10
# genres/jazz/jazz.00061.wav, segment:1
# genres/jazz/jazz.00061.wav, segment:2
# genres/jazz/jazz.00061.wav, segment:3
# genres/jazz/jazz.00061.wav, segment:4
# genres/jazz/jazz.00061.wav, segment:5
# genres/jazz/jazz.00061.wav, segment:6
# genres/jazz/jazz.00061.wav, segment:7
# genres/jazz/jazz.00061.wav, segment:8
# genres/jazz/jazz.00061.wav, segment:9
# genres/jazz/jazz.00061.wav, segment:10
# genres/jazz/jazz.00013.wav, segment:1
# genres/jazz/jazz.00013.wav, segment:2
# genres/jazz/jazz.00013.wav, segment:3
# genres/jazz/jazz.00013.wav, segment:4
# genres/jazz/jazz.00013.wav, segment:5
# genres/jazz/jazz.00013.wav, segment:6
# genres/jazz/jazz.00013.wav, segment:7
# genres/jazz/jazz.00013.wav, segment:8
# genres/jazz/jazz.00013.wav, segment:9
# genres/jazz/jazz.00013.wav, segment:10
# genres/jazz/jazz.00048.wav, segment:1
# genres/jazz/jazz.00048.wav, segment:2
# genres/jazz/jazz.00048.wav, segment:3
# genres/jazz/jazz.00048.wav, segment:4
# genres/jazz/jazz.00048.wav, segment:5
# genres/jazz/jazz.00048.wav, segment:6
# genres/jazz/jazz.00048.wav, segment:7
# genres/jazz/jazz.00048.wav, segment:8
# genres/jazz/jazz.00048.wav, segment:9
# genres/jazz/jazz.00048.wav, segment:10
# genres/jazz/jazz.00089.wav, segment:1
# genres/jazz/jazz.00089.wav, segment:2
# genres/jazz/jazz.00089.wav, segment:3
# genres/jazz/jazz.00089.wav, segment:4
# genres/jazz/jazz.00089.wav, segment:5
# genres/jazz/jazz.00089.wav, segment:6
# genres/jazz/jazz.00089.wav, segment:7
# genres/jazz/jazz.00089.wav, segment:8
# genres/jazz/jazz.00089.wav, segment:9
# genres/jazz/jazz.00089.wav, segment:10
# genres/jazz/jazz.00034.wav, segment:1
# genres/jazz/jazz.00034.wav, segment:2
# genres/jazz/jazz.00034.wav, segment:3
# genres/jazz/jazz.00034.wav, segment:4
# genres/jazz/jazz.00034.wav, segment:5
# genres/jazz/jazz.00034.wav, segment:6
# genres/jazz/jazz.00034.wav, segment:7
# genres/jazz/jazz.00034.wav, segment:8
# genres/jazz/jazz.00034.wav, segment:9
# genres/jazz/jazz.00034.wav, segment:10
# genres/jazz/jazz.00000.wav, segment:1
# genres/jazz/jazz.00000.wav, segment:2
# genres/jazz/jazz.00000.wav, segment:3
# genres/jazz/jazz.00000.wav, segment:4
# genres/jazz/jazz.00000.wav, segment:5
# genres/jazz/jazz.00000.wav, segment:6
# genres/jazz/jazz.00000.wav, segment:7
# genres/jazz/jazz.00000.wav, segment:8
# genres/jazz/jazz.00000.wav, segment:9
# genres/jazz/jazz.00000.wav, segment:10
# genres/jazz/jazz.00046.wav, segment:1
# genres/jazz/jazz.00046.wav, segment:2
# genres/jazz/jazz.00046.wav, segment:3
# genres/jazz/jazz.00046.wav, segment:4
# genres/jazz/jazz.00046.wav, segment:5
# genres/jazz/jazz.00046.wav, segment:6
# genres/jazz/jazz.00046.wav, segment:7
# genres/jazz/jazz.00046.wav, segment:8
# genres/jazz/jazz.00046.wav, segment:9
# genres/jazz/jazz.00046.wav, segment:10
# genres/jazz/jazz.00085.wav, segment:1
# genres/jazz/jazz.00085.wav, segment:2
# genres/jazz/jazz.00085.wav, segment:3
# genres/jazz/jazz.00085.wav, segment:4
# genres/jazz/jazz.00085.wav, segment:5
# genres/jazz/jazz.00085.wav, segment:6
# genres/jazz/jazz.00085.wav, segment:7
# genres/jazz/jazz.00085.wav, segment:8
# genres/jazz/jazz.00085.wav, segment:9
# genres/jazz/jazz.00085.wav, segment:10
# genres/jazz/jazz.00097.wav, segment:1
# genres/jazz/jazz.00097.wav, segment:2
# genres/jazz/jazz.00097.wav, segment:3
# genres/jazz/jazz.00097.wav, segment:4
# genres/jazz/jazz.00097.wav, segment:5
# genres/jazz/jazz.00097.wav, segment:6
# genres/jazz/jazz.00097.wav, segment:7
# genres/jazz/jazz.00097.wav, segment:8
# genres/jazz/jazz.00097.wav, segment:9
# genres/jazz/jazz.00097.wav, segment:10
# genres/jazz/jazz.00062.wav, segment:1
# genres/jazz/jazz.00062.wav, segment:2
# genres/jazz/jazz.00062.wav, segment:3
# genres/jazz/jazz.00062.wav, segment:4
# genres/jazz/jazz.00062.wav, segment:5
# genres/jazz/jazz.00062.wav, segment:6
# genres/jazz/jazz.00062.wav, segment:7
# genres/jazz/jazz.00062.wav, segment:8
# genres/jazz/jazz.00062.wav, segment:9
# genres/jazz/jazz.00062.wav, segment:10
# genres/jazz/jazz.00006.wav, segment:1
# genres/jazz/jazz.00006.wav, segment:2
# genres/jazz/jazz.00006.wav, segment:3
# genres/jazz/jazz.00006.wav, segment:4
# genres/jazz/jazz.00006.wav, segment:5
# genres/jazz/jazz.00006.wav, segment:6
# genres/jazz/jazz.00006.wav, segment:7
# genres/jazz/jazz.00006.wav, segment:8
# genres/jazz/jazz.00006.wav, segment:9
# genres/jazz/jazz.00006.wav, segment:10
# genres/jazz/jazz.00088.wav, segment:1
# genres/jazz/jazz.00088.wav, segment:2
# genres/jazz/jazz.00088.wav, segment:3
# genres/jazz/jazz.00088.wav, segment:4
# genres/jazz/jazz.00088.wav, segment:5
# genres/jazz/jazz.00088.wav, segment:6
# genres/jazz/jazz.00088.wav, segment:7
# genres/jazz/jazz.00088.wav, segment:8
# genres/jazz/jazz.00088.wav, segment:9
# genres/jazz/jazz.00088.wav, segment:10
# genres/jazz/jazz.00044.wav, segment:1
# genres/jazz/jazz.00044.wav, segment:2
# genres/jazz/jazz.00044.wav, segment:3
# genres/jazz/jazz.00044.wav, segment:4
# genres/jazz/jazz.00044.wav, segment:5
# genres/jazz/jazz.00044.wav, segment:6
# genres/jazz/jazz.00044.wav, segment:7
# genres/jazz/jazz.00044.wav, segment:8
# genres/jazz/jazz.00044.wav, segment:9
# genres/jazz/jazz.00044.wav, segment:10
# genres/jazz/jazz.00033.wav, segment:1
# genres/jazz/jazz.00033.wav, segment:2
# genres/jazz/jazz.00033.wav, segment:3
# genres/jazz/jazz.00033.wav, segment:4
# genres/jazz/jazz.00033.wav, segment:5
# genres/jazz/jazz.00033.wav, segment:6
# genres/jazz/jazz.00033.wav, segment:7
# genres/jazz/jazz.00033.wav, segment:8
# genres/jazz/jazz.00033.wav, segment:9
# genres/jazz/jazz.00033.wav, segment:10
# genres/jazz/jazz.00030.wav, segment:1
# genres/jazz/jazz.00030.wav, segment:2
# genres/jazz/jazz.00030.wav, segment:3
# genres/jazz/jazz.00030.wav, segment:4
# genres/jazz/jazz.00030.wav, segment:5
# genres/jazz/jazz.00030.wav, segment:6
# genres/jazz/jazz.00030.wav, segment:7
# genres/jazz/jazz.00030.wav, segment:8
# genres/jazz/jazz.00030.wav, segment:9
# genres/jazz/jazz.00030.wav, segment:10
# genres/jazz/jazz.00029.wav, segment:1
# genres/jazz/jazz.00029.wav, segment:2
# genres/jazz/jazz.00029.wav, segment:3
# genres/jazz/jazz.00029.wav, segment:4
# genres/jazz/jazz.00029.wav, segment:5
# genres/jazz/jazz.00029.wav, segment:6
# genres/jazz/jazz.00029.wav, segment:7
# genres/jazz/jazz.00029.wav, segment:8
# genres/jazz/jazz.00029.wav, segment:9
# genres/jazz/jazz.00029.wav, segment:10
# genres/jazz/jazz.00042.wav, segment:1
# genres/jazz/jazz.00042.wav, segment:2
# genres/jazz/jazz.00042.wav, segment:3
# genres/jazz/jazz.00042.wav, segment:4
# genres/jazz/jazz.00042.wav, segment:5
# genres/jazz/jazz.00042.wav, segment:6
# genres/jazz/jazz.00042.wav, segment:7
# genres/jazz/jazz.00042.wav, segment:8
# genres/jazz/jazz.00042.wav, segment:9
# genres/jazz/jazz.00042.wav, segment:10
# genres/jazz/jazz.00004.wav, segment:1
# genres/jazz/jazz.00004.wav, segment:2
# genres/jazz/jazz.00004.wav, segment:3
# genres/jazz/jazz.00004.wav, segment:4
# genres/jazz/jazz.00004.wav, segment:5
# genres/jazz/jazz.00004.wav, segment:6
# genres/jazz/jazz.00004.wav, segment:7
# genres/jazz/jazz.00004.wav, segment:8
# genres/jazz/jazz.00004.wav, segment:9
# genres/jazz/jazz.00004.wav, segment:10
# genres/jazz/jazz.00028.wav, segment:1
# genres/jazz/jazz.00028.wav, segment:2
# genres/jazz/jazz.00028.wav, segment:3
# genres/jazz/jazz.00028.wav, segment:4
# genres/jazz/jazz.00028.wav, segment:5
# genres/jazz/jazz.00028.wav, segment:6
# genres/jazz/jazz.00028.wav, segment:7
# genres/jazz/jazz.00028.wav, segment:8
# genres/jazz/jazz.00028.wav, segment:9
# genres/jazz/jazz.00028.wav, segment:10
# genres/jazz/jazz.00086.wav, segment:1
# genres/jazz/jazz.00086.wav, segment:2
# genres/jazz/jazz.00086.wav, segment:3
# genres/jazz/jazz.00086.wav, segment:4
# genres/jazz/jazz.00086.wav, segment:5
# genres/jazz/jazz.00086.wav, segment:6
# genres/jazz/jazz.00086.wav, segment:7
# genres/jazz/jazz.00086.wav, segment:8
# genres/jazz/jazz.00086.wav, segment:9
# genres/jazz/jazz.00086.wav, segment:10
# genres/jazz/jazz.00010.wav, segment:1
# genres/jazz/jazz.00010.wav, segment:2
# genres/jazz/jazz.00010.wav, segment:3
# genres/jazz/jazz.00010.wav, segment:4
# genres/jazz/jazz.00010.wav, segment:5
# genres/jazz/jazz.00010.wav, segment:6
# genres/jazz/jazz.00010.wav, segment:7
# genres/jazz/jazz.00010.wav, segment:8
# genres/jazz/jazz.00010.wav, segment:9
# genres/jazz/jazz.00010.wav, segment:10
# genres/jazz/jazz.00007.wav, segment:1
# genres/jazz/jazz.00007.wav, segment:2
# genres/jazz/jazz.00007.wav, segment:3
# genres/jazz/jazz.00007.wav, segment:4
# genres/jazz/jazz.00007.wav, segment:5
# genres/jazz/jazz.00007.wav, segment:6
# genres/jazz/jazz.00007.wav, segment:7
# genres/jazz/jazz.00007.wav, segment:8
# genres/jazz/jazz.00007.wav, segment:9
# genres/jazz/jazz.00007.wav, segment:10
# genres/jazz/jazz.00082.wav, segment:1
# genres/jazz/jazz.00082.wav, segment:2
# genres/jazz/jazz.00082.wav, segment:3
# genres/jazz/jazz.00082.wav, segment:4
# genres/jazz/jazz.00082.wav, segment:5
# genres/jazz/jazz.00082.wav, segment:6
# genres/jazz/jazz.00082.wav, segment:7
# genres/jazz/jazz.00082.wav, segment:8
# genres/jazz/jazz.00082.wav, segment:9
# genres/jazz/jazz.00082.wav, segment:10
# genres/jazz/jazz.00052.wav, segment:1
# genres/jazz/jazz.00052.wav, segment:2
# genres/jazz/jazz.00052.wav, segment:3
# genres/jazz/jazz.00052.wav, segment:4
# genres/jazz/jazz.00052.wav, segment:5
# genres/jazz/jazz.00052.wav, segment:6
# genres/jazz/jazz.00052.wav, segment:7
# genres/jazz/jazz.00052.wav, segment:8
# genres/jazz/jazz.00052.wav, segment:9
# genres/jazz/jazz.00052.wav, segment:10
# genres/jazz/jazz.00063.wav, segment:1
# genres/jazz/jazz.00063.wav, segment:2
# genres/jazz/jazz.00063.wav, segment:3
# genres/jazz/jazz.00063.wav, segment:4
# genres/jazz/jazz.00063.wav, segment:5
# genres/jazz/jazz.00063.wav, segment:6
# genres/jazz/jazz.00063.wav, segment:7
# genres/jazz/jazz.00063.wav, segment:8
# genres/jazz/jazz.00063.wav, segment:9
# genres/jazz/jazz.00063.wav, segment:10
# genres/jazz/jazz.00050.wav, segment:1
# genres/jazz/jazz.00050.wav, segment:2
# genres/jazz/jazz.00050.wav, segment:3
# genres/jazz/jazz.00050.wav, segment:4
# genres/jazz/jazz.00050.wav, segment:5
# genres/jazz/jazz.00050.wav, segment:6
# genres/jazz/jazz.00050.wav, segment:7
# genres/jazz/jazz.00050.wav, segment:8
# genres/jazz/jazz.00050.wav, segment:9
# genres/jazz/jazz.00050.wav, segment:10
# genres/jazz/jazz.00026.wav, segment:1
# genres/jazz/jazz.00026.wav, segment:2
# genres/jazz/jazz.00026.wav, segment:3
# genres/jazz/jazz.00026.wav, segment:4
# genres/jazz/jazz.00026.wav, segment:5
# genres/jazz/jazz.00026.wav, segment:6
# genres/jazz/jazz.00026.wav, segment:7
# genres/jazz/jazz.00026.wav, segment:8
# genres/jazz/jazz.00026.wav, segment:9
# genres/jazz/jazz.00026.wav, segment:10
# genres/jazz/jazz.00038.wav, segment:1
# genres/jazz/jazz.00038.wav, segment:2
# genres/jazz/jazz.00038.wav, segment:3
# genres/jazz/jazz.00038.wav, segment:4
# genres/jazz/jazz.00038.wav, segment:5
# genres/jazz/jazz.00038.wav, segment:6
# genres/jazz/jazz.00038.wav, segment:7
# genres/jazz/jazz.00038.wav, segment:8
# genres/jazz/jazz.00038.wav, segment:9
# genres/jazz/jazz.00038.wav, segment:10
# genres/jazz/jazz.00076.wav, segment:1
# genres/jazz/jazz.00076.wav, segment:2
# genres/jazz/jazz.00076.wav, segment:3
# genres/jazz/jazz.00076.wav, segment:4
# genres/jazz/jazz.00076.wav, segment:5
# genres/jazz/jazz.00076.wav, segment:6
# genres/jazz/jazz.00076.wav, segment:7
# genres/jazz/jazz.00076.wav, segment:8
# genres/jazz/jazz.00076.wav, segment:9
# genres/jazz/jazz.00076.wav, segment:10
# genres/jazz/jazz.00073.wav, segment:1
# genres/jazz/jazz.00073.wav, segment:2
# genres/jazz/jazz.00073.wav, segment:3
# genres/jazz/jazz.00073.wav, segment:4
# genres/jazz/jazz.00073.wav, segment:5
# genres/jazz/jazz.00073.wav, segment:6
# genres/jazz/jazz.00073.wav, segment:7
# genres/jazz/jazz.00073.wav, segment:8
# genres/jazz/jazz.00073.wav, segment:9
# genres/jazz/jazz.00073.wav, segment:10
# genres/jazz/jazz.00025.wav, segment:1
# genres/jazz/jazz.00025.wav, segment:2
# genres/jazz/jazz.00025.wav, segment:3
# genres/jazz/jazz.00025.wav, segment:4
# genres/jazz/jazz.00025.wav, segment:5
# genres/jazz/jazz.00025.wav, segment:6
# genres/jazz/jazz.00025.wav, segment:7
# genres/jazz/jazz.00025.wav, segment:8
# genres/jazz/jazz.00025.wav, segment:9
# genres/jazz/jazz.00025.wav, segment:10
# genres/jazz/jazz.00036.wav, segment:1
# genres/jazz/jazz.00036.wav, segment:2
# genres/jazz/jazz.00036.wav, segment:3
# genres/jazz/jazz.00036.wav, segment:4
# genres/jazz/jazz.00036.wav, segment:5
# genres/jazz/jazz.00036.wav, segment:6
# genres/jazz/jazz.00036.wav, segment:7
# genres/jazz/jazz.00036.wav, segment:8
# genres/jazz/jazz.00036.wav, segment:9
# genres/jazz/jazz.00036.wav, segment:10
# genres/jazz/jazz.00096.wav, segment:1
# genres/jazz/jazz.00096.wav, segment:2
# genres/jazz/jazz.00096.wav, segment:3
# genres/jazz/jazz.00096.wav, segment:4
# genres/jazz/jazz.00096.wav, segment:5
# genres/jazz/jazz.00096.wav, segment:6
# genres/jazz/jazz.00096.wav, segment:7
# genres/jazz/jazz.00096.wav, segment:8
# genres/jazz/jazz.00096.wav, segment:9
# genres/jazz/jazz.00096.wav, segment:10
# genres/jazz/jazz.00016.wav, segment:1
# genres/jazz/jazz.00016.wav, segment:2
# genres/jazz/jazz.00016.wav, segment:3
# genres/jazz/jazz.00016.wav, segment:4
# genres/jazz/jazz.00016.wav, segment:5
# genres/jazz/jazz.00016.wav, segment:6
# genres/jazz/jazz.00016.wav, segment:7
# genres/jazz/jazz.00016.wav, segment:8
# genres/jazz/jazz.00016.wav, segment:9
# genres/jazz/jazz.00016.wav, segment:10
# genres/jazz/jazz.00080.wav, segment:1
# genres/jazz/jazz.00080.wav, segment:2
# genres/jazz/jazz.00080.wav, segment:3
# genres/jazz/jazz.00080.wav, segment:4
# genres/jazz/jazz.00080.wav, segment:5
# genres/jazz/jazz.00080.wav, segment:6
# genres/jazz/jazz.00080.wav, segment:7
# genres/jazz/jazz.00080.wav, segment:8
# genres/jazz/jazz.00080.wav, segment:9
# genres/jazz/jazz.00080.wav, segment:10
# genres/jazz/jazz.00099.wav, segment:1
# genres/jazz/jazz.00099.wav, segment:2
# genres/jazz/jazz.00099.wav, segment:3
# genres/jazz/jazz.00099.wav, segment:4
# genres/jazz/jazz.00099.wav, segment:5
# genres/jazz/jazz.00099.wav, segment:6
# genres/jazz/jazz.00099.wav, segment:7
# genres/jazz/jazz.00099.wav, segment:8
# genres/jazz/jazz.00099.wav, segment:9
# genres/jazz/jazz.00099.wav, segment:10
# genres/jazz/jazz.00018.wav, segment:1
# genres/jazz/jazz.00018.wav, segment:2
# genres/jazz/jazz.00018.wav, segment:3
# genres/jazz/jazz.00018.wav, segment:4
# genres/jazz/jazz.00018.wav, segment:5
# genres/jazz/jazz.00018.wav, segment:6
# genres/jazz/jazz.00018.wav, segment:7
# genres/jazz/jazz.00018.wav, segment:8
# genres/jazz/jazz.00018.wav, segment:9
# genres/jazz/jazz.00018.wav, segment:10
# genres/jazz/jazz.00069.wav, segment:1
# genres/jazz/jazz.00069.wav, segment:2
# genres/jazz/jazz.00069.wav, segment:3
# genres/jazz/jazz.00069.wav, segment:4
# genres/jazz/jazz.00069.wav, segment:5
# genres/jazz/jazz.00069.wav, segment:6
# genres/jazz/jazz.00069.wav, segment:7
# genres/jazz/jazz.00069.wav, segment:8
# genres/jazz/jazz.00069.wav, segment:9
# genres/jazz/jazz.00069.wav, segment:10
# genres/jazz/jazz.00075.wav, segment:1
# genres/jazz/jazz.00075.wav, segment:2
# genres/jazz/jazz.00075.wav, segment:3
# genres/jazz/jazz.00075.wav, segment:4
# genres/jazz/jazz.00075.wav, segment:5
# genres/jazz/jazz.00075.wav, segment:6
# genres/jazz/jazz.00075.wav, segment:7
# genres/jazz/jazz.00075.wav, segment:8
# genres/jazz/jazz.00075.wav, segment:9
# genres/jazz/jazz.00075.wav, segment:10
# genres/jazz/jazz.00072.wav, segment:1
# genres/jazz/jazz.00072.wav, segment:2
# genres/jazz/jazz.00072.wav, segment:3
# genres/jazz/jazz.00072.wav, segment:4
# genres/jazz/jazz.00072.wav, segment:5
# genres/jazz/jazz.00072.wav, segment:6
# genres/jazz/jazz.00072.wav, segment:7
# genres/jazz/jazz.00072.wav, segment:8
# genres/jazz/jazz.00072.wav, segment:9
# genres/jazz/jazz.00072.wav, segment:10
# genres/jazz/jazz.00051.wav, segment:1
# genres/jazz/jazz.00051.wav, segment:2
# genres/jazz/jazz.00051.wav, segment:3
# genres/jazz/jazz.00051.wav, segment:4
# genres/jazz/jazz.00051.wav, segment:5
# genres/jazz/jazz.00051.wav, segment:6
# genres/jazz/jazz.00051.wav, segment:7
# genres/jazz/jazz.00051.wav, segment:8
# genres/jazz/jazz.00051.wav, segment:9
# genres/jazz/jazz.00051.wav, segment:10
# genres/jazz/jazz.00055.wav, segment:1
# genres/jazz/jazz.00055.wav, segment:2
# genres/jazz/jazz.00055.wav, segment:3
# genres/jazz/jazz.00055.wav, segment:4
# genres/jazz/jazz.00055.wav, segment:5
# genres/jazz/jazz.00055.wav, segment:6
# genres/jazz/jazz.00055.wav, segment:7
# genres/jazz/jazz.00055.wav, segment:8
# genres/jazz/jazz.00055.wav, segment:9
# genres/jazz/jazz.00055.wav, segment:10
# genres/jazz/jazz.00057.wav, segment:1
# genres/jazz/jazz.00057.wav, segment:2
# genres/jazz/jazz.00057.wav, segment:3
# genres/jazz/jazz.00057.wav, segment:4
# genres/jazz/jazz.00057.wav, segment:5
# genres/jazz/jazz.00057.wav, segment:6
# genres/jazz/jazz.00057.wav, segment:7
# genres/jazz/jazz.00057.wav, segment:8
# genres/jazz/jazz.00057.wav, segment:9
# genres/jazz/jazz.00057.wav, segment:10
# genres/jazz/jazz.00032.wav, segment:1
# genres/jazz/jazz.00032.wav, segment:2
# genres/jazz/jazz.00032.wav, segment:3
# genres/jazz/jazz.00032.wav, segment:4
# genres/jazz/jazz.00032.wav, segment:5
# genres/jazz/jazz.00032.wav, segment:6
# genres/jazz/jazz.00032.wav, segment:7
# genres/jazz/jazz.00032.wav, segment:8
# genres/jazz/jazz.00032.wav, segment:9
# genres/jazz/jazz.00032.wav, segment:10
# genres/jazz/jazz.00079.wav, segment:1
# genres/jazz/jazz.00079.wav, segment:2
# genres/jazz/jazz.00079.wav, segment:3
# genres/jazz/jazz.00079.wav, segment:4
# genres/jazz/jazz.00079.wav, segment:5
# genres/jazz/jazz.00079.wav, segment:6
# genres/jazz/jazz.00079.wav, segment:7
# genres/jazz/jazz.00079.wav, segment:8
# genres/jazz/jazz.00079.wav, segment:9
# genres/jazz/jazz.00079.wav, segment:10
# genres/jazz/jazz.00019.wav, segment:1
# genres/jazz/jazz.00019.wav, segment:2
# genres/jazz/jazz.00019.wav, segment:3
# genres/jazz/jazz.00019.wav, segment:4
# genres/jazz/jazz.00019.wav, segment:5
# genres/jazz/jazz.00019.wav, segment:6
# genres/jazz/jazz.00019.wav, segment:7
# genres/jazz/jazz.00019.wav, segment:8
# genres/jazz/jazz.00019.wav, segment:9
# genres/jazz/jazz.00019.wav, segment:10
# genres/jazz/jazz.00095.wav, segment:1
# genres/jazz/jazz.00095.wav, segment:2
# genres/jazz/jazz.00095.wav, segment:3
# genres/jazz/jazz.00095.wav, segment:4
# genres/jazz/jazz.00095.wav, segment:5
# genres/jazz/jazz.00095.wav, segment:6
# genres/jazz/jazz.00095.wav, segment:7
# genres/jazz/jazz.00095.wav, segment:8
# genres/jazz/jazz.00095.wav, segment:9
# genres/jazz/jazz.00095.wav, segment:10
# genres/jazz/jazz.00003.wav, segment:1
# genres/jazz/jazz.00003.wav, segment:2
# genres/jazz/jazz.00003.wav, segment:3
# genres/jazz/jazz.00003.wav, segment:4
# genres/jazz/jazz.00003.wav, segment:5
# genres/jazz/jazz.00003.wav, segment:6
# genres/jazz/jazz.00003.wav, segment:7
# genres/jazz/jazz.00003.wav, segment:8
# genres/jazz/jazz.00003.wav, segment:9
# genres/jazz/jazz.00003.wav, segment:10
# genres/jazz/jazz.00008.wav, segment:1
# genres/jazz/jazz.00008.wav, segment:2
# genres/jazz/jazz.00008.wav, segment:3
# genres/jazz/jazz.00008.wav, segment:4
# genres/jazz/jazz.00008.wav, segment:5
# genres/jazz/jazz.00008.wav, segment:6
# genres/jazz/jazz.00008.wav, segment:7
# genres/jazz/jazz.00008.wav, segment:8
# genres/jazz/jazz.00008.wav, segment:9
# genres/jazz/jazz.00008.wav, segment:10
# genres/jazz/jazz.00090.wav, segment:1
# genres/jazz/jazz.00090.wav, segment:2
# genres/jazz/jazz.00090.wav, segment:3
# genres/jazz/jazz.00090.wav, segment:4
# genres/jazz/jazz.00090.wav, segment:5
# genres/jazz/jazz.00090.wav, segment:6
# genres/jazz/jazz.00090.wav, segment:7
# genres/jazz/jazz.00090.wav, segment:8
# genres/jazz/jazz.00090.wav, segment:9
# genres/jazz/jazz.00090.wav, segment:10
# genres/jazz/jazz.00078.wav, segment:1
# genres/jazz/jazz.00078.wav, segment:2
# genres/jazz/jazz.00078.wav, segment:3
# genres/jazz/jazz.00078.wav, segment:4
# genres/jazz/jazz.00078.wav, segment:5
# genres/jazz/jazz.00078.wav, segment:6
# genres/jazz/jazz.00078.wav, segment:7
# genres/jazz/jazz.00078.wav, segment:8
# genres/jazz/jazz.00078.wav, segment:9
# genres/jazz/jazz.00078.wav, segment:10
# genres/jazz/jazz.00081.wav, segment:1
# genres/jazz/jazz.00081.wav, segment:2
# genres/jazz/jazz.00081.wav, segment:3
# genres/jazz/jazz.00081.wav, segment:4
# genres/jazz/jazz.00081.wav, segment:5
# genres/jazz/jazz.00081.wav, segment:6
# genres/jazz/jazz.00081.wav, segment:7
# genres/jazz/jazz.00081.wav, segment:8
# genres/jazz/jazz.00081.wav, segment:9
# genres/jazz/jazz.00081.wav, segment:10
# genres/jazz/jazz.00071.wav, segment:1
# genres/jazz/jazz.00071.wav, segment:2
# genres/jazz/jazz.00071.wav, segment:3
# genres/jazz/jazz.00071.wav, segment:4
# genres/jazz/jazz.00071.wav, segment:5
# genres/jazz/jazz.00071.wav, segment:6
# genres/jazz/jazz.00071.wav, segment:7
# genres/jazz/jazz.00071.wav, segment:8
# genres/jazz/jazz.00071.wav, segment:9
# genres/jazz/jazz.00071.wav, segment:10
# genres/jazz/jazz.00023.wav, segment:1
# genres/jazz/jazz.00023.wav, segment:2
# genres/jazz/jazz.00023.wav, segment:3
# genres/jazz/jazz.00023.wav, segment:4
# genres/jazz/jazz.00023.wav, segment:5
# genres/jazz/jazz.00023.wav, segment:6
# genres/jazz/jazz.00023.wav, segment:7
# genres/jazz/jazz.00023.wav, segment:8
# genres/jazz/jazz.00023.wav, segment:9
# genres/jazz/jazz.00023.wav, segment:10
# genres/jazz/jazz.00005.wav, segment:1
# genres/jazz/jazz.00005.wav, segment:2
# genres/jazz/jazz.00005.wav, segment:3
# genres/jazz/jazz.00005.wav, segment:4
# genres/jazz/jazz.00005.wav, segment:5
# genres/jazz/jazz.00005.wav, segment:6
# genres/jazz/jazz.00005.wav, segment:7
# genres/jazz/jazz.00005.wav, segment:8
# genres/jazz/jazz.00005.wav, segment:9
# genres/jazz/jazz.00005.wav, segment:10
# genres/jazz/jazz.00070.wav, segment:1
# genres/jazz/jazz.00070.wav, segment:2
# genres/jazz/jazz.00070.wav, segment:3
# genres/jazz/jazz.00070.wav, segment:4
# genres/jazz/jazz.00070.wav, segment:5
# genres/jazz/jazz.00070.wav, segment:6
# genres/jazz/jazz.00070.wav, segment:7
# genres/jazz/jazz.00070.wav, segment:8
# genres/jazz/jazz.00070.wav, segment:9
# genres/jazz/jazz.00070.wav, segment:10
# genres/jazz/jazz.00014.wav, segment:1
# genres/jazz/jazz.00014.wav, segment:2
# genres/jazz/jazz.00014.wav, segment:3
# genres/jazz/jazz.00014.wav, segment:4
# genres/jazz/jazz.00014.wav, segment:5
# genres/jazz/jazz.00014.wav, segment:6
# genres/jazz/jazz.00014.wav, segment:7
# genres/jazz/jazz.00014.wav, segment:8
# genres/jazz/jazz.00014.wav, segment:9
# genres/jazz/jazz.00014.wav, segment:10
# genres/jazz/jazz.00021.wav, segment:1
# genres/jazz/jazz.00021.wav, segment:2
# genres/jazz/jazz.00021.wav, segment:3
# genres/jazz/jazz.00021.wav, segment:4
# genres/jazz/jazz.00021.wav, segment:5
# genres/jazz/jazz.00021.wav, segment:6
# genres/jazz/jazz.00021.wav, segment:7
# genres/jazz/jazz.00021.wav, segment:8
# genres/jazz/jazz.00021.wav, segment:9
# genres/jazz/jazz.00021.wav, segment:10
# genres/jazz/jazz.00094.wav, segment:1
# genres/jazz/jazz.00094.wav, segment:2
# genres/jazz/jazz.00094.wav, segment:3
# genres/jazz/jazz.00094.wav, segment:4
# genres/jazz/jazz.00094.wav, segment:5
# genres/jazz/jazz.00094.wav, segment:6
# genres/jazz/jazz.00094.wav, segment:7
# genres/jazz/jazz.00094.wav, segment:8
# genres/jazz/jazz.00094.wav, segment:9
# genres/jazz/jazz.00094.wav, segment:10
# genres/jazz/jazz.00031.wav, segment:1
# genres/jazz/jazz.00031.wav, segment:2
# genres/jazz/jazz.00031.wav, segment:3
# genres/jazz/jazz.00031.wav, segment:4
# genres/jazz/jazz.00031.wav, segment:5
# genres/jazz/jazz.00031.wav, segment:6
# genres/jazz/jazz.00031.wav, segment:7
# genres/jazz/jazz.00031.wav, segment:8
# genres/jazz/jazz.00031.wav, segment:9
# genres/jazz/jazz.00031.wav, segment:10
# genres/jazz/jazz.00054.wav, segment:1
# genres/jazz/jazz.00054.wav, segment:2
# genres/jazz/jazz.00054.wav, segment:3
# genres/jazz/jazz.00054.wav, segment:4
# genres/jazz/jazz.00054.wav, segment:5
# genres/jazz/jazz.00054.wav, segment:6
# genres/jazz/jazz.00054.wav, segment:7
# genres/jazz/jazz.00054.wav, segment:8
# genres/jazz/jazz.00054.wav, segment:9
# genres/jazz/jazz.00054.wav, segment:10
# genres/jazz/jazz.00035.wav, segment:1
# genres/jazz/jazz.00035.wav, segment:2
# genres/jazz/jazz.00035.wav, segment:3
# genres/jazz/jazz.00035.wav, segment:4
# genres/jazz/jazz.00035.wav, segment:5
# genres/jazz/jazz.00035.wav, segment:6
# genres/jazz/jazz.00035.wav, segment:7
# genres/jazz/jazz.00035.wav, segment:8
# genres/jazz/jazz.00035.wav, segment:9
# genres/jazz/jazz.00035.wav, segment:10
# genres/jazz/jazz.00049.wav, segment:1
# genres/jazz/jazz.00049.wav, segment:2
# genres/jazz/jazz.00049.wav, segment:3
# genres/jazz/jazz.00049.wav, segment:4
# genres/jazz/jazz.00049.wav, segment:5
# genres/jazz/jazz.00049.wav, segment:6
# genres/jazz/jazz.00049.wav, segment:7
# genres/jazz/jazz.00049.wav, segment:8
# genres/jazz/jazz.00049.wav, segment:9
# genres/jazz/jazz.00049.wav, segment:10
# genres/jazz/jazz.00067.wav, segment:1
# genres/jazz/jazz.00067.wav, segment:2
# genres/jazz/jazz.00067.wav, segment:3
# genres/jazz/jazz.00067.wav, segment:4
# genres/jazz/jazz.00067.wav, segment:5
# genres/jazz/jazz.00067.wav, segment:6
# genres/jazz/jazz.00067.wav, segment:7
# genres/jazz/jazz.00067.wav, segment:8
# genres/jazz/jazz.00067.wav, segment:9
# genres/jazz/jazz.00067.wav, segment:10
#
# Processing: country
# genres/country/country.00057.wav, segment:1
# genres/country/country.00057.wav, segment:2
# genres/country/country.00057.wav, segment:3
# genres/country/country.00057.wav, segment:4
# genres/country/country.00057.wav, segment:5
# genres/country/country.00057.wav, segment:6
# genres/country/country.00057.wav, segment:7
# genres/country/country.00057.wav, segment:8
# genres/country/country.00057.wav, segment:9
# genres/country/country.00057.wav, segment:10
# genres/country/country.00077.wav, segment:1
# genres/country/country.00077.wav, segment:2
# genres/country/country.00077.wav, segment:3
# genres/country/country.00077.wav, segment:4
# genres/country/country.00077.wav, segment:5
# genres/country/country.00077.wav, segment:6
# genres/country/country.00077.wav, segment:7
# genres/country/country.00077.wav, segment:8
# genres/country/country.00077.wav, segment:9
# genres/country/country.00077.wav, segment:10
# genres/country/country.00082.wav, segment:1
# genres/country/country.00082.wav, segment:2
# genres/country/country.00082.wav, segment:3
# genres/country/country.00082.wav, segment:4
# genres/country/country.00082.wav, segment:5
# genres/country/country.00082.wav, segment:6
# genres/country/country.00082.wav, segment:7
# genres/country/country.00082.wav, segment:8
# genres/country/country.00082.wav, segment:9
# genres/country/country.00082.wav, segment:10
# genres/country/country.00012.wav, segment:1
# genres/country/country.00012.wav, segment:2
# genres/country/country.00012.wav, segment:3
# genres/country/country.00012.wav, segment:4
# genres/country/country.00012.wav, segment:5
# genres/country/country.00012.wav, segment:6
# genres/country/country.00012.wav, segment:7
# genres/country/country.00012.wav, segment:8
# genres/country/country.00012.wav, segment:9
# genres/country/country.00012.wav, segment:10
# genres/country/country.00078.wav, segment:1
# genres/country/country.00078.wav, segment:2
# genres/country/country.00078.wav, segment:3
# genres/country/country.00078.wav, segment:4
# genres/country/country.00078.wav, segment:5
# genres/country/country.00078.wav, segment:6
# genres/country/country.00078.wav, segment:7
# genres/country/country.00078.wav, segment:8
# genres/country/country.00078.wav, segment:9
# genres/country/country.00078.wav, segment:10
# genres/country/country.00010.wav, segment:1
# genres/country/country.00010.wav, segment:2
# genres/country/country.00010.wav, segment:3
# genres/country/country.00010.wav, segment:4
# genres/country/country.00010.wav, segment:5
# genres/country/country.00010.wav, segment:6
# genres/country/country.00010.wav, segment:7
# genres/country/country.00010.wav, segment:8
# genres/country/country.00010.wav, segment:9
# genres/country/country.00010.wav, segment:10
# genres/country/country.00050.wav, segment:1
# genres/country/country.00050.wav, segment:2
# genres/country/country.00050.wav, segment:3
# genres/country/country.00050.wav, segment:4
# genres/country/country.00050.wav, segment:5
# genres/country/country.00050.wav, segment:6
# genres/country/country.00050.wav, segment:7
# genres/country/country.00050.wav, segment:8
# genres/country/country.00050.wav, segment:9
# genres/country/country.00050.wav, segment:10
# genres/country/country.00015.wav, segment:1
# genres/country/country.00015.wav, segment:2
# genres/country/country.00015.wav, segment:3
# genres/country/country.00015.wav, segment:4
# genres/country/country.00015.wav, segment:5
# genres/country/country.00015.wav, segment:6
# genres/country/country.00015.wav, segment:7
# genres/country/country.00015.wav, segment:8
# genres/country/country.00015.wav, segment:9
# genres/country/country.00015.wav, segment:10
# genres/country/country.00074.wav, segment:1
# genres/country/country.00074.wav, segment:2
# genres/country/country.00074.wav, segment:3
# genres/country/country.00074.wav, segment:4
# genres/country/country.00074.wav, segment:5
# genres/country/country.00074.wav, segment:6
# genres/country/country.00074.wav, segment:7
# genres/country/country.00074.wav, segment:8
# genres/country/country.00074.wav, segment:9
# genres/country/country.00074.wav, segment:10
# genres/country/country.00018.wav, segment:1
# genres/country/country.00018.wav, segment:2
# genres/country/country.00018.wav, segment:3
# genres/country/country.00018.wav, segment:4
# genres/country/country.00018.wav, segment:5
# genres/country/country.00018.wav, segment:6
# genres/country/country.00018.wav, segment:7
# genres/country/country.00018.wav, segment:8
# genres/country/country.00018.wav, segment:9
# genres/country/country.00018.wav, segment:10
# genres/country/country.00039.wav, segment:1
# genres/country/country.00039.wav, segment:2
# genres/country/country.00039.wav, segment:3
# genres/country/country.00039.wav, segment:4
# genres/country/country.00039.wav, segment:5
# genres/country/country.00039.wav, segment:6
# genres/country/country.00039.wav, segment:7
# genres/country/country.00039.wav, segment:8
# genres/country/country.00039.wav, segment:9
# genres/country/country.00039.wav, segment:10
# genres/country/country.00085.wav, segment:1
# genres/country/country.00085.wav, segment:2
# genres/country/country.00085.wav, segment:3
# genres/country/country.00085.wav, segment:4
# genres/country/country.00085.wav, segment:5
# genres/country/country.00085.wav, segment:6
# genres/country/country.00085.wav, segment:7
# genres/country/country.00085.wav, segment:8
# genres/country/country.00085.wav, segment:9
# genres/country/country.00085.wav, segment:10
# genres/country/country.00088.wav, segment:1
# genres/country/country.00088.wav, segment:2
# genres/country/country.00088.wav, segment:3
# genres/country/country.00088.wav, segment:4
# genres/country/country.00088.wav, segment:5
# genres/country/country.00088.wav, segment:6
# genres/country/country.00088.wav, segment:7
# genres/country/country.00088.wav, segment:8
# genres/country/country.00088.wav, segment:9
# genres/country/country.00088.wav, segment:10
# genres/country/country.00092.wav, segment:1
# genres/country/country.00092.wav, segment:2
# genres/country/country.00092.wav, segment:3
# genres/country/country.00092.wav, segment:4
# genres/country/country.00092.wav, segment:5
# genres/country/country.00092.wav, segment:6
# genres/country/country.00092.wav, segment:7
# genres/country/country.00092.wav, segment:8
# genres/country/country.00092.wav, segment:9
# genres/country/country.00092.wav, segment:10
# genres/country/country.00038.wav, segment:1
# genres/country/country.00038.wav, segment:2
# genres/country/country.00038.wav, segment:3
# genres/country/country.00038.wav, segment:4
# genres/country/country.00038.wav, segment:5
# genres/country/country.00038.wav, segment:6
# genres/country/country.00038.wav, segment:7
# genres/country/country.00038.wav, segment:8
# genres/country/country.00038.wav, segment:9
# genres/country/country.00038.wav, segment:10
# genres/country/country.00060.wav, segment:1
# genres/country/country.00060.wav, segment:2
# genres/country/country.00060.wav, segment:3
# genres/country/country.00060.wav, segment:4
# genres/country/country.00060.wav, segment:5
# genres/country/country.00060.wav, segment:6
# genres/country/country.00060.wav, segment:7
# genres/country/country.00060.wav, segment:8
# genres/country/country.00060.wav, segment:9
# genres/country/country.00060.wav, segment:10
# genres/country/country.00001.wav, segment:1
# genres/country/country.00001.wav, segment:2
# genres/country/country.00001.wav, segment:3
# genres/country/country.00001.wav, segment:4
# genres/country/country.00001.wav, segment:5
# genres/country/country.00001.wav, segment:6
# genres/country/country.00001.wav, segment:7
# genres/country/country.00001.wav, segment:8
# genres/country/country.00001.wav, segment:9
# genres/country/country.00001.wav, segment:10
# genres/country/country.00024.wav, segment:1
# genres/country/country.00024.wav, segment:2
# genres/country/country.00024.wav, segment:3
# genres/country/country.00024.wav, segment:4
# genres/country/country.00024.wav, segment:5
# genres/country/country.00024.wav, segment:6
# genres/country/country.00024.wav, segment:7
# genres/country/country.00024.wav, segment:8
# genres/country/country.00024.wav, segment:9
# genres/country/country.00024.wav, segment:10
# genres/country/country.00017.wav, segment:1
# genres/country/country.00017.wav, segment:2
# genres/country/country.00017.wav, segment:3
# genres/country/country.00017.wav, segment:4
# genres/country/country.00017.wav, segment:5
# genres/country/country.00017.wav, segment:6
# genres/country/country.00017.wav, segment:7
# genres/country/country.00017.wav, segment:8
# genres/country/country.00017.wav, segment:9
# genres/country/country.00017.wav, segment:10
# genres/country/country.00095.wav, segment:1
# genres/country/country.00095.wav, segment:2
# genres/country/country.00095.wav, segment:3
# genres/country/country.00095.wav, segment:4
# genres/country/country.00095.wav, segment:5
# genres/country/country.00095.wav, segment:6
# genres/country/country.00095.wav, segment:7
# genres/country/country.00095.wav, segment:8
# genres/country/country.00095.wav, segment:9
# genres/country/country.00095.wav, segment:10
# genres/country/country.00096.wav, segment:1
# genres/country/country.00096.wav, segment:2
# genres/country/country.00096.wav, segment:3
# genres/country/country.00096.wav, segment:4
# genres/country/country.00096.wav, segment:5
# genres/country/country.00096.wav, segment:6
# genres/country/country.00096.wav, segment:7
# genres/country/country.00096.wav, segment:8
# genres/country/country.00096.wav, segment:9
# genres/country/country.00096.wav, segment:10
# genres/country/country.00041.wav, segment:1
# genres/country/country.00041.wav, segment:2
# genres/country/country.00041.wav, segment:3
# genres/country/country.00041.wav, segment:4
# genres/country/country.00041.wav, segment:5
# genres/country/country.00041.wav, segment:6
# genres/country/country.00041.wav, segment:7
# genres/country/country.00041.wav, segment:8
# genres/country/country.00041.wav, segment:9
# genres/country/country.00041.wav, segment:10
# genres/country/country.00056.wav, segment:1
# genres/country/country.00056.wav, segment:2
# genres/country/country.00056.wav, segment:3
# genres/country/country.00056.wav, segment:4
# genres/country/country.00056.wav, segment:5
# genres/country/country.00056.wav, segment:6
# genres/country/country.00056.wav, segment:7
# genres/country/country.00056.wav, segment:8
# ...
# genres/metal/metal.00069.wav, segment:2
# genres/metal/metal.00069.wav, segment:3
# genres/metal/metal.00069.wav, segment:4
# genres/metal/metal.00069.wav, segment:5
# genres/metal/metal.00069.wav, segment:6
# genres/metal/metal.00069.wav, segment:7
# genres/metal/metal.00069.wav, segment:8
# genres/metal/metal.00069.wav, segment:9
# genres/metal/metal.00069.wav, segment:10
# genres/metal/metal.00039.wav, segment:1
# genres/metal/metal.00039.wav, segment:2
# genres/metal/metal.00039.wav, segment:3
# genres/metal/metal.00039.wav, segment:4
# genres/metal/metal.00039.wav, segment:5
# genres/metal/metal.00039.wav, segment:6
# genres/metal/metal.00039.wav, segment:7
# genres/metal/metal.00039.wav, segment:8
# genres/metal/metal.00039.wav, segment:9
# genres/metal/metal.00039.wav, segment:10
# genres/metal/metal.00019.wav, segment:1
# genres/metal/metal.00019.wav, segment:2
# genres/metal/metal.00019.wav, segment:3
# genres/metal/metal.00019.wav, segment:4
# genres/metal/metal.00019.wav, segment:5
# genres/metal/metal.00019.wav, segment:6
# genres/metal/metal.00019.wav, segment:7
# genres/metal/metal.00019.wav, segment:8
# genres/metal/metal.00019.wav, segment:9
# genres/metal/metal.00019.wav, segment:10
# genres/metal/metal.00042.wav, segment:1
# genres/metal/metal.00042.wav, segment:2
# genres/metal/metal.00042.wav, segment:3
# genres/metal/metal.00042.wav, segment:4
# genres/metal/metal.00042.wav, segment:5
# genres/metal/metal.00042.wav, segment:6
# genres/metal/metal.00042.wav, segment:7
# genres/metal/metal.00042.wav, segment:8
# genres/metal/metal.00042.wav, segment:9
# genres/metal/metal.00042.wav, segment:10
# genres/metal/metal.00079.wav, segment:1
# genres/metal/metal.00079.wav, segment:2
# genres/metal/metal.00079.wav, segment:3
# genres/metal/metal.00079.wav, segment:4
# genres/metal/metal.00079.wav, segment:5
# genres/metal/metal.00079.wav, segment:6
# genres/metal/metal.00079.wav, segment:7
# genres/metal/metal.00079.wav, segment:8
# genres/metal/metal.00079.wav, segment:9
# genres/metal/metal.00079.wav, segment:10
# genres/metal/metal.00082.wav, segment:1
# genres/metal/metal.00082.wav, segment:2
# genres/metal/metal.00082.wav, segment:3
# genres/metal/metal.00082.wav, segment:4
# genres/metal/metal.00082.wav, segment:5
# genres/metal/metal.00082.wav, segment:6
# genres/metal/metal.00082.wav, segment:7
# genres/metal/metal.00082.wav, segment:8
# genres/metal/metal.00082.wav, segment:9
# genres/metal/metal.00082.wav, segment:10
# genres/metal/metal.00053.wav, segment:1
# genres/metal/metal.00053.wav, segment:2
# genres/metal/metal.00053.wav, segment:3
# genres/metal/metal.00053.wav, segment:4
# genres/metal/metal.00053.wav, segment:5
# genres/metal/metal.00053.wav, segment:6
# genres/metal/metal.00053.wav, segment:7
# genres/metal/metal.00053.wav, segment:8
# genres/metal/metal.00053.wav, segment:9
# genres/metal/metal.00053.wav, segment:10
# genres/metal/metal.00000.wav, segment:1
# genres/metal/metal.00000.wav, segment:2
# genres/metal/metal.00000.wav, segment:3
# genres/metal/metal.00000.wav, segment:4
# genres/metal/metal.00000.wav, segment:5
# genres/metal/metal.00000.wav, segment:6
# genres/metal/metal.00000.wav, segment:7
# genres/metal/metal.00000.wav, segment:8
# genres/metal/metal.00000.wav, segment:9
# genres/metal/metal.00000.wav, segment:10
# genres/metal/metal.00099.wav, segment:1
# genres/metal/metal.00099.wav, segment:2
# genres/metal/metal.00099.wav, segment:3
# genres/metal/metal.00099.wav, segment:4
# genres/metal/metal.00099.wav, segment:5
# genres/metal/metal.00099.wav, segment:6
# genres/metal/metal.00099.wav, segment:7
# genres/metal/metal.00099.wav, segment:8
# genres/metal/metal.00099.wav, segment:9
# genres/metal/metal.00099.wav, segment:10
# genres/metal/metal.00012.wav, segment:1
# genres/metal/metal.00012.wav, segment:2
# genres/metal/metal.00012.wav, segment:3
# genres/metal/metal.00012.wav, segment:4
# genres/metal/metal.00012.wav, segment:5
# genres/metal/metal.00012.wav, segment:6
# genres/metal/metal.00012.wav, segment:7
# genres/metal/metal.00012.wav, segment:8
# genres/metal/metal.00012.wav, segment:9
# genres/metal/metal.00012.wav, segment:10
# genres/metal/metal.00016.wav, segment:1
# genres/metal/metal.00016.wav, segment:2
# genres/metal/metal.00016.wav, segment:3
# genres/metal/metal.00016.wav, segment:4
# genres/metal/metal.00016.wav, segment:5
# genres/metal/metal.00016.wav, segment:6
# genres/metal/metal.00016.wav, segment:7
# genres/metal/metal.00016.wav, segment:8
# genres/metal/metal.00016.wav, segment:9
# genres/metal/metal.00016.wav, segment:10
# genres/metal/metal.00004.wav, segment:1
# genres/metal/metal.00004.wav, segment:2
# genres/metal/metal.00004.wav, segment:3
# genres/metal/metal.00004.wav, segment:4
# genres/metal/metal.00004.wav, segment:5
# genres/metal/metal.00004.wav, segment:6
# genres/metal/metal.00004.wav, segment:7
# genres/metal/metal.00004.wav, segment:8
# genres/metal/metal.00004.wav, segment:9
# genres/metal/metal.00004.wav, segment:10
# genres/metal/metal.00002.wav, segment:1
# genres/metal/metal.00002.wav, segment:2
# genres/metal/metal.00002.wav, segment:3
# genres/metal/metal.00002.wav, segment:4
# genres/metal/metal.00002.wav, segment:5
# genres/metal/metal.00002.wav, segment:6
# genres/metal/metal.00002.wav, segment:7
# genres/metal/metal.00002.wav, segment:8
# genres/metal/metal.00002.wav, segment:9
# genres/metal/metal.00002.wav, segment:10
# genres/metal/metal.00060.wav, segment:1
# genres/metal/metal.00060.wav, segment:2
# genres/metal/metal.00060.wav, segment:3
# genres/metal/metal.00060.wav, segment:4
# genres/metal/metal.00060.wav, segment:5
# genres/metal/metal.00060.wav, segment:6
# genres/metal/metal.00060.wav, segment:7
# genres/metal/metal.00060.wav, segment:8
# genres/metal/metal.00060.wav, segment:9
# genres/metal/metal.00060.wav, segment:10
# genres/metal/metal.00072.wav, segment:1
# genres/metal/metal.00072.wav, segment:2
# genres/metal/metal.00072.wav, segment:3
# genres/metal/metal.00072.wav, segment:4
# genres/metal/metal.00072.wav, segment:5
# genres/metal/metal.00072.wav, segment:6
# genres/metal/metal.00072.wav, segment:7
# genres/metal/metal.00072.wav, segment:8
# genres/metal/metal.00072.wav, segment:9
# genres/metal/metal.00072.wav, segment:10
# genres/metal/metal.00003.wav, segment:1
# genres/metal/metal.00003.wav, segment:2
# genres/metal/metal.00003.wav, segment:3
# genres/metal/metal.00003.wav, segment:4
# genres/metal/metal.00003.wav, segment:5
# genres/metal/metal.00003.wav, segment:6
# genres/metal/metal.00003.wav, segment:7
# genres/metal/metal.00003.wav, segment:8
# genres/metal/metal.00003.wav, segment:9
# genres/metal/metal.00003.wav, segment:10
# genres/metal/metal.00026.wav, segment:1
# genres/metal/metal.00026.wav, segment:2
# genres/metal/metal.00026.wav, segment:3
# genres/metal/metal.00026.wav, segment:4
# genres/metal/metal.00026.wav, segment:5
# genres/metal/metal.00026.wav, segment:6
# genres/metal/metal.00026.wav, segment:7
# genres/metal/metal.00026.wav, segment:8
# genres/metal/metal.00026.wav, segment:9
# genres/metal/metal.00026.wav, segment:10
# genres/metal/metal.00051.wav, segment:1
# genres/metal/metal.00051.wav, segment:2
# genres/metal/metal.00051.wav, segment:3
# genres/metal/metal.00051.wav, segment:4
# genres/metal/metal.00051.wav, segment:5
# genres/metal/metal.00051.wav, segment:6
# genres/metal/metal.00051.wav, segment:7
# genres/metal/metal.00051.wav, segment:8
# genres/metal/metal.00051.wav, segment:9
# genres/metal/metal.00051.wav, segment:10
# genres/metal/metal.00085.wav, segment:1
# genres/metal/metal.00085.wav, segment:2
# genres/metal/metal.00085.wav, segment:3
# genres/metal/metal.00085.wav, segment:4
# genres/metal/metal.00085.wav, segment:5
# genres/metal/metal.00085.wav, segment:6
# genres/metal/metal.00085.wav, segment:7
# genres/metal/metal.00085.wav, segment:8
# genres/metal/metal.00085.wav, segment:9
# genres/metal/metal.00085.wav, segment:10
# genres/metal/metal.00022.wav, segment:1
# genres/metal/metal.00022.wav, segment:2
# genres/metal/metal.00022.wav, segment:3
# genres/metal/metal.00022.wav, segment:4
# genres/metal/metal.00022.wav, segment:5
# genres/metal/metal.00022.wav, segment:6
# genres/metal/metal.00022.wav, segment:7
# genres/metal/metal.00022.wav, segment:8
# genres/metal/metal.00022.wav, segment:9
# genres/metal/metal.00022.wav, segment:10
# genres/metal/metal.00013.wav, segment:1
# genres/metal/metal.00013.wav, segment:2
# genres/metal/metal.00013.wav, segment:3
# genres/metal/metal.00013.wav, segment:4
# genres/metal/metal.00013.wav, segment:5
# genres/metal/metal.00013.wav, segment:6
# genres/metal/metal.00013.wav, segment:7
# genres/metal/metal.00013.wav, segment:8
# genres/metal/metal.00013.wav, segment:9
# genres/metal/metal.00013.wav, segment:10
# genres/metal/metal.00056.wav, segment:1
# genres/metal/metal.00056.wav, segment:2
# genres/metal/metal.00056.wav, segment:3
# genres/metal/metal.00056.wav, segment:4
# genres/metal/metal.00056.wav, segment:5
# genres/metal/metal.00056.wav, segment:6
# genres/metal/metal.00056.wav, segment:7
# genres/metal/metal.00056.wav, segment:8
# genres/metal/metal.00056.wav, segment:9
# genres/metal/metal.00056.wav, segment:10
# genres/metal/metal.00041.wav, segment:1
# genres/metal/metal.00041.wav, segment:2
# genres/metal/metal.00041.wav, segment:3
# genres/metal/metal.00041.wav, segment:4
# genres/metal/metal.00041.wav, segment:5
# genres/metal/metal.00041.wav, segment:6
# genres/metal/metal.00041.wav, segment:7
# genres/metal/metal.00041.wav, segment:8
# genres/metal/metal.00041.wav, segment:9
# genres/metal/metal.00041.wav, segment:10
# genres/metal/metal.00091.wav, segment:1
# genres/metal/metal.00091.wav, segment:2
# genres/metal/metal.00091.wav, segment:3
# genres/metal/metal.00091.wav, segment:4
# genres/metal/metal.00091.wav, segment:5
# genres/metal/metal.00091.wav, segment:6
# genres/metal/metal.00091.wav, segment:7
# genres/metal/metal.00091.wav, segment:8
# genres/metal/metal.00091.wav, segment:9
# genres/metal/metal.00091.wav, segment:10
# genres/metal/metal.00045.wav, segment:1
# genres/metal/metal.00045.wav, segment:2
# genres/metal/metal.00045.wav, segment:3
# genres/metal/metal.00045.wav, segment:4
# genres/metal/metal.00045.wav, segment:5
# genres/metal/metal.00045.wav, segment:6
# genres/metal/metal.00045.wav, segment:7
# genres/metal/metal.00045.wav, segment:8
# genres/metal/metal.00045.wav, segment:9
# genres/metal/metal.00045.wav, segment:10
# genres/metal/metal.00029.wav, segment:1
# genres/metal/metal.00029.wav, segment:2
# genres/metal/metal.00029.wav, segment:3
# genres/metal/metal.00029.wav, segment:4
# genres/metal/metal.00029.wav, segment:5
# genres/metal/metal.00029.wav, segment:6
# genres/metal/metal.00029.wav, segment:7
# genres/metal/metal.00029.wav, segment:8
# genres/metal/metal.00029.wav, segment:9
# genres/metal/metal.00029.wav, segment:10
# genres/metal/metal.00084.wav, segment:1
# genres/metal/metal.00084.wav, segment:2
# genres/metal/metal.00084.wav, segment:3
# genres/metal/metal.00084.wav, segment:4
# genres/metal/metal.00084.wav, segment:5
# genres/metal/metal.00084.wav, segment:6
# genres/metal/metal.00084.wav, segment:7
# genres/metal/metal.00084.wav, segment:8
# genres/metal/metal.00084.wav, segment:9
# genres/metal/metal.00084.wav, segment:10
# genres/metal/metal.00058.wav, segment:1
# genres/metal/metal.00058.wav, segment:2
# genres/metal/metal.00058.wav, segment:3
# genres/metal/metal.00058.wav, segment:4
# genres/metal/metal.00058.wav, segment:5
# genres/metal/metal.00058.wav, segment:6
# genres/metal/metal.00058.wav, segment:7
# genres/metal/metal.00058.wav, segment:8
# genres/metal/metal.00058.wav, segment:9
# genres/metal/metal.00058.wav, segment:10
# genres/metal/metal.00057.wav, segment:1
# genres/metal/metal.00057.wav, segment:2
# genres/metal/metal.00057.wav, segment:3
# genres/metal/metal.00057.wav, segment:4
# genres/metal/metal.00057.wav, segment:5
# genres/metal/metal.00057.wav, segment:6
# genres/metal/metal.00057.wav, segment:7
# genres/metal/metal.00057.wav, segment:8
# genres/metal/metal.00057.wav, segment:9
# genres/metal/metal.00057.wav, segment:10
# genres/metal/metal.00073.wav, segment:1
# genres/metal/metal.00073.wav, segment:2
# genres/metal/metal.00073.wav, segment:3
# genres/metal/metal.00073.wav, segment:4
# genres/metal/metal.00073.wav, segment:5
# genres/metal/metal.00073.wav, segment:6
# genres/metal/metal.00073.wav, segment:7
# genres/metal/metal.00073.wav, segment:8
# genres/metal/metal.00073.wav, segment:9
# genres/metal/metal.00073.wav, segment:10
# genres/metal/metal.00028.wav, segment:1
# genres/metal/metal.00028.wav, segment:2
# genres/metal/metal.00028.wav, segment:3
# genres/metal/metal.00028.wav, segment:4
# genres/metal/metal.00028.wav, segment:5
# genres/metal/metal.00028.wav, segment:6
# genres/metal/metal.00028.wav, segment:7
# genres/metal/metal.00028.wav, segment:8
# genres/metal/metal.00028.wav, segment:9
# genres/metal/metal.00028.wav, segment:10
# genres/metal/metal.00093.wav, segment:1
# genres/metal/metal.00093.wav, segment:2
# genres/metal/metal.00093.wav, segment:3
# genres/metal/metal.00093.wav, segment:4
# genres/metal/metal.00093.wav, segment:5
# genres/metal/metal.00093.wav, segment:6
# genres/metal/metal.00093.wav, segment:7
# genres/metal/metal.00093.wav, segment:8
# genres/metal/metal.00093.wav, segment:9
# genres/metal/metal.00093.wav, segment:10
# genres/metal/metal.00059.wav, segment:1
# genres/metal/metal.00059.wav, segment:2
# genres/metal/metal.00059.wav, segment:3
# genres/metal/metal.00059.wav, segment:4
# genres/metal/metal.00059.wav, segment:5
# genres/metal/metal.00059.wav, segment:6
# genres/metal/metal.00059.wav, segment:7
# genres/metal/metal.00059.wav, segment:8
# genres/metal/metal.00059.wav, segment:9
# genres/metal/metal.00059.wav, segment:10
# genres/metal/metal.00011.wav, segment:1
# genres/metal/metal.00011.wav, segment:2
# genres/metal/metal.00011.wav, segment:3
# genres/metal/metal.00011.wav, segment:4
# genres/metal/metal.00011.wav, segment:5
# genres/metal/metal.00011.wav, segment:6
# genres/metal/metal.00011.wav, segment:7
# genres/metal/metal.00011.wav, segment:8
# genres/metal/metal.00011.wav, segment:9
# genres/metal/metal.00011.wav, segment:10
# genres/metal/metal.00075.wav, segment:1
# genres/metal/metal.00075.wav, segment:2
# genres/metal/metal.00075.wav, segment:3
# genres/metal/metal.00075.wav, segment:4
# genres/metal/metal.00075.wav, segment:5
# genres/metal/metal.00075.wav, segment:6
# genres/metal/metal.00075.wav, segment:7
# genres/metal/metal.00075.wav, segment:8
# genres/metal/metal.00075.wav, segment:9
# genres/metal/metal.00075.wav, segment:10
# genres/metal/metal.00070.wav, segment:1
# genres/metal/metal.00070.wav, segment:2
# genres/metal/metal.00070.wav, segment:3
# genres/metal/metal.00070.wav, segment:4
# genres/metal/metal.00070.wav, segment:5
# genres/metal/metal.00070.wav, segment:6
# genres/metal/metal.00070.wav, segment:7
# genres/metal/metal.00070.wav, segment:8
# genres/metal/metal.00070.wav, segment:9
# genres/metal/metal.00070.wav, segment:10
# genres/metal/metal.00074.wav, segment:1
# genres/metal/metal.00074.wav, segment:2
# genres/metal/metal.00074.wav, segment:3
# genres/metal/metal.00074.wav, segment:4
# genres/metal/metal.00074.wav, segment:5
# genres/metal/metal.00074.wav, segment:6
# genres/metal/metal.00074.wav, segment:7
# genres/metal/metal.00074.wav, segment:8
# genres/metal/metal.00074.wav, segment:9
# genres/metal/metal.00074.wav, segment:10
# genres/metal/metal.00050.wav, segment:1
# genres/metal/metal.00050.wav, segment:2
# genres/metal/metal.00050.wav, segment:3
# genres/metal/metal.00050.wav, segment:4
# genres/metal/metal.00050.wav, segment:5
# genres/metal/metal.00050.wav, segment:6
# genres/metal/metal.00050.wav, segment:7
# genres/metal/metal.00050.wav, segment:8
# genres/metal/metal.00050.wav, segment:9
# genres/metal/metal.00050.wav, segment:10
# genres/metal/metal.00048.wav, segment:1
# genres/metal/metal.00048.wav, segment:2
# genres/metal/metal.00048.wav, segment:3
# genres/metal/metal.00048.wav, segment:4
# genres/metal/metal.00048.wav, segment:5
# genres/metal/metal.00048.wav, segment:6
# genres/metal/metal.00048.wav, segment:7
# genres/metal/metal.00048.wav, segment:8
# genres/metal/metal.00048.wav, segment:9
# genres/metal/metal.00048.wav, segment:10
# genres/metal/metal.00092.wav, segment:1
# genres/metal/metal.00092.wav, segment:2
# genres/metal/metal.00092.wav, segment:3
# genres/metal/metal.00092.wav, segment:4
# genres/metal/metal.00092.wav, segment:5
# genres/metal/metal.00092.wav, segment:6
# genres/metal/metal.00092.wav, segment:7
# genres/metal/metal.00092.wav, segment:8
# genres/metal/metal.00092.wav, segment:9
# genres/metal/metal.00092.wav, segment:10

# %%
def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.

    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split

    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    """Generates RNN-LSTM model

    :param input_shape (tuple): Shape of input set
    :return model: RNN-LSTM model
    """

    # build network topology
    model = keras.Sequential()

    # 2 LSTM layers
    model.add(keras.layers.LSTM(64, input_shape=input_shape, return_sequences=True))
    model.add(keras.layers.LSTM(64))

    # dense layer
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(10, activation='softmax'))

    return model


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2]) # 130, 13
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 130, 64)           19968
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 57,802
# Trainable params: 57,802
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 188/188 [==============================] - 30s 158ms/step - loss: 2.1855 - accuracy: 0.2134 - val_loss: 2.0496 - val_accuracy: 0.3400
# Epoch 2/30
# 188/188 [==============================] - 29s 152ms/step - loss: 1.9540 - accuracy: 0.3297 - val_loss: 1.7974 - val_accuracy: 0.3813
# Epoch 3/30
# 188/188 [==============================] - 29s 153ms/step - loss: 1.7417 - accuracy: 0.3912 - val_loss: 1.6256 - val_accuracy: 0.4347
# Epoch 4/30
# 188/188 [==============================] - 28s 150ms/step - loss: 1.6153 - accuracy: 0.4257 - val_loss: 1.5439 - val_accuracy: 0.4653
# Epoch 5/30
# 188/188 [==============================] - 30s 161ms/step - loss: 1.5397 - accuracy: 0.4484 - val_loss: 1.4791 - val_accuracy: 0.4907
# Epoch 6/30
# 188/188 [==============================] - 31s 164ms/step - loss: 1.4713 - accuracy: 0.4822 - val_loss: 1.4277 - val_accuracy: 0.4953
# Epoch 7/30
# 188/188 [==============================] - 29s 156ms/step - loss: 1.4196 - accuracy: 0.4937 - val_loss: 1.4134 - val_accuracy: 0.5040
# Epoch 8/30
# 188/188 [==============================] - 29s 154ms/step - loss: 1.3714 - accuracy: 0.5046 - val_loss: 1.3714 - val_accuracy: 0.5160
# Epoch 9/30
# 188/188 [==============================] - 30s 160ms/step - loss: 1.3302 - accuracy: 0.5254 - val_loss: 1.3581 - val_accuracy: 0.5193
# Epoch 10/30
# 188/188 [==============================] - 30s 158ms/step - loss: 1.2980 - accuracy: 0.5423 - val_loss: 1.3178 - val_accuracy: 0.5313
# Epoch 11/30
# 188/188 [==============================] - 30s 160ms/step - loss: 1.2701 - accuracy: 0.5541 - val_loss: 1.3134 - val_accuracy: 0.5387
# Epoch 12/30
# 188/188 [==============================] - 30s 161ms/step - loss: 1.2319 - accuracy: 0.5616 - val_loss: 1.2979 - val_accuracy: 0.5340
# Epoch 13/30
# 188/188 [==============================] - 30s 159ms/step - loss: 1.2097 - accuracy: 0.5705 - val_loss: 1.2897 - val_accuracy: 0.5527
# Epoch 14/30
# 188/188 [==============================] - 28s 150ms/step - loss: 1.1780 - accuracy: 0.5863 - val_loss: 1.2715 - val_accuracy: 0.5527
# Epoch 15/30
# 188/188 [==============================] - 29s 153ms/step - loss: 1.1583 - accuracy: 0.5968 - val_loss: 1.2550 - val_accuracy: 0.5700
# Epoch 16/30
# 188/188 [==============================] - 28s 151ms/step - loss: 1.1276 - accuracy: 0.6018 - val_loss: 1.2457 - val_accuracy: 0.5700
# Epoch 17/30
# 188/188 [==============================] - 29s 152ms/step - loss: 1.1090 - accuracy: 0.6170 - val_loss: 1.2568 - val_accuracy: 0.5620
# Epoch 18/30
# 188/188 [==============================] - 30s 161ms/step - loss: 1.1099 - accuracy: 0.6136 - val_loss: 1.2425 - val_accuracy: 0.5693
# Epoch 19/30
# 188/188 [==============================] - 29s 153ms/step - loss: 1.0762 - accuracy: 0.6238 - val_loss: 1.2441 - val_accuracy: 0.5680
# Epoch 20/30
# 188/188 [==============================] - 30s 159ms/step - loss: 1.0460 - accuracy: 0.6377 - val_loss: 1.2209 - val_accuracy: 0.5733
# Epoch 21/30
# 188/188 [==============================] - 31s 165ms/step - loss: 1.0299 - accuracy: 0.6468 - val_loss: 1.2151 - val_accuracy: 0.5807
# Epoch 22/30
# 188/188 [==============================] - 31s 163ms/step - loss: 1.0084 - accuracy: 0.6560 - val_loss: 1.2175 - val_accuracy: 0.5847
# Epoch 23/30
# 188/188 [==============================] - 31s 165ms/step - loss: 1.0000 - accuracy: 0.6568 - val_loss: 1.2104 - val_accuracy: 0.5907
# Epoch 24/30
# 188/188 [==============================] - 31s 164ms/step - loss: 0.9788 - accuracy: 0.6700 - val_loss: 1.2083 - val_accuracy: 0.5953
# Epoch 25/30
# 188/188 [==============================] - 31s 166ms/step - loss: 0.9661 - accuracy: 0.6745 - val_loss: 1.1838 - val_accuracy: 0.5967
# Epoch 26/30
# 188/188 [==============================] - 31s 167ms/step - loss: 0.9569 - accuracy: 0.6730 - val_loss: 1.1907 - val_accuracy: 0.5887
# Epoch 27/30
# 188/188 [==============================] - 30s 160ms/step - loss: 0.9288 - accuracy: 0.6823 - val_loss: 1.1984 - val_accuracy: 0.5947
# Epoch 28/30
# 188/188 [==============================] - 30s 161ms/step - loss: 0.9151 - accuracy: 0.6862 - val_loss: 1.1755 - val_accuracy: 0.5947
# Epoch 29/30
# 188/188 [==============================] - 29s 156ms/step - loss: 0.9088 - accuracy: 0.6988 - val_loss: 1.2122 - val_accuracy: 0.5913
# Epoch 30/30
# 188/188 [==============================] - 29s 152ms/step - loss: 0.9134 - accuracy: 0.6935 - val_loss: 1.1647 - val_accuracy: 0.6033
# 79/79 - 3s - loss: 1.1534 - accuracy: 0.6126
#
# Test accuracy: 0.6126450300216675

# %%
# plot accuracy/error for training and validation
plot_history(history)

# %%
# evaluate model on test set
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print('\nTest accuracy:', test_acc)
